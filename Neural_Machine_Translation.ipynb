# %% [markdown]
# # Assignment #4
#
# ---
#
# ## Group Members
#
# | Name          | ID      |
# |---------------|---------|
# | Abdelrahman Mohamed Mohamed Abdelmotlb      | 20010851  |
# | Abdelrahman Aladdin Essayed   | 20010824  |
# | Adel Mahmoud Mohamed   | 20010769    |
#
# ---

# %% [markdown]
# ## Learning Objectives
# In this problem, we will use [PyTorch](https://pytorch.org/) to implement a sequence-to-sequence (seq2seq) transformer model to build a nerual machine translation (NMT) system, which translates from French to English.

# %% [markdown]
# ## Writing Code
# Look for the keyword "TODO" and fill in your code in the empty space.
# You can edit code in the other parts of the notebook too, which can be useful for debugging, but be careful to avoid breaking the provided code.

# %% [markdown]
# ## Installing Packages
#
# Install PyTorch using pip. See [https://pytorch.org/](https://pytorch.org/) if you want to install it on your computer.
# In addition, we will also be needing [huggingface](https://huggingface.co/)'s `transformers` and `datasets` libraries, and [nltk](https://www.nltk.org/) to compute the BLEU score.

# %%
# Pytorch is typically already installed in Google Colab (uncomment to install):
# !pip install torch==1.8.0
# or for GPU support:
# !pip install torch==1.8.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install transformers==4.27.0
# !pip install datasets==2.10.0
# NLTK is typically also already installed in Google Colab (uncomment to install):
# !pip install nltk==3.8.1
# Out:
# Requirement already satisfied: transformers==4.27.0 in /usr/local/lib/python3.10/dist-packages (4.27.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (2.32.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.0) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (2024.12.14)
# Collecting datasets==2.10.0
#   Using cached datasets-2.10.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (1.26.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (17.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.70.14)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.11.1->datasets==2.10.0) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (3.11.10)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (24.2)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (1.18.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.10.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.10.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.10.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.10.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.10.0) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.10.0) (1.17.0)
# Using cached datasets-2.10.0-py3-none-any.whl (469 kB)
# Installing collected packages: datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.2.0
#     Uninstalling datasets-3.2.0:
#       Successfully uninstalled datasets-3.2.0
# Successfully installed datasets-2.10.0

# %% [markdown]
# ## Download NMT data

# %% [markdown]
# We first download the data for NMT, which contains pairs of parallel sentences.

# %%
# !wget --quiet https://princeton-nlp.github.io/cos484/assignments/a4/resources.zip
# !unzip -qo resources.zip

# %%
# !pip install --upgrade datasets fsspec
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.10.0)
# Collecting datasets
#   Using cached datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (2024.9.0)
# Collecting fsspec
#   Using cached fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Using cached datasets-3.2.0-py3-none-any.whl (480 kB)
# Installing collected packages: datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.10.0
#     Uninstalling datasets-2.10.0:
#       Successfully uninstalled datasets-2.10.0
# Successfully installed datasets-3.2.0

# %% [markdown]
# ## Data preprocessing
# In this section we will write code to load and tokenize the data for NMT.
#
#
# The parallel data is provided as huggingface datasets, one for each split of `train`, `validation` and `test`. We load it via the `load_from_disk` method and inspect its features. If you'd like to know more about these dataset objects, have a look at [this tutorial](https://huggingface.co/docs/datasets/access).

# %%
from datasets import load_from_disk
# !ls resources/parallel_en_fr_corpus

raw_text_datasets = load_from_disk("resources/parallel_en_fr_corpus")
print("Summary of splits:", raw_text_datasets)
print("First training example:", raw_text_datasets["train"][0])
# Out:
# dataset_dict.json  test  train	validation
# Summary of splits: DatasetDict({
#     train: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 8701
#     })
#     validation: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 485
#     })
#     test: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 486
#     })
# })
# First training example: {'text_en': 'i m tough .', 'text_fr': 'je suis dure .'}

# %% [markdown]
# You are also provided with two pre-trained tokenizers for the source and target languages respectively, which we can load with the hugginface transfomers library. [This tutorial](https://huggingface.co/docs/transformers/preprocessing#natural-language-processing) provides an introduction to using pre-trained tokenizers and the powerful `AutoTokenizer` class. The tokenizers are based on byte-pair encodings which break words into smaller units. This is aimed at reducing the sparsity of words, as subwords can be shared between different rare words. If you are interested in learning more, see the paper [Neural Machine Translation of Rare Words with Subword Units](https://www.aclweb.org/anthology/P16-1162.pdf).

# %%
from transformers import AutoTokenizer
source_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_fr")
target_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_en")

# print("vocab:", target_tokenizer.get_vocab())
print("Vocab size of source language:", source_tokenizer.vocab_size)
print("Vocab size of target language:", target_tokenizer.vocab_size)

# As a demonstration, we will the following English sentence to tokens.
example_sentence = "we have an example"
tokenizer_output = target_tokenizer(example_sentence)
print("\n*** Example ***")
print("Example sentence:", example_sentence)
print("Tokenizer output:", tokenizer_output)

# We convert every token id to its associated string, but find the special character ▁ which indicates the beginning of a word.
# Note that very common words are represented by a single token, while others are split into subunits due to the small vocab size.
# Also note that †he tokenizer already adds special tokens to the beginning and end of the sentence.
decoded_sequence = [target_tokenizer.decode(token) for token in tokenizer_output["input_ids"]]
print("Tokens:", decoded_sequence)

# By replacing the special character ▁ with whitespace, we can reconstruct a legibile sentence,
# which differs from the original example by special tokens, includings <unk> tokens, and minor whitespace differences.
reconstructed = "".join(decoded_sequence).replace("▁", " ")
print("Reconstructed sentence", reconstructed)
# Out:
# Vocab size of source language: 3200
# Vocab size of target language: 3200
#
# *** Example ***
# Example sentence: we have an example
# Tokenizer output: {'input_ids': [1, 64, 324, 103, 266, 1490, 92, 2], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1]}
# Tokens: ['<s>', '▁we', '▁have', '▁an', '▁ex', 'amp', 'le', '</s>']
# Reconstructed sentence <s> we have an example</s>

# %% [markdown]
# We now want to convert the entire dataset to token ids.
# Specifically, we want to use the tokenizers to create a dataset with
# features "encoder_input_ids" and "decoder_input_ids", which both have type `List[int]`
# and which will later be the inputs to our encoder-decoder model. We will implement this using the powerful `map` function. You can find its API reference [here](https://huggingface.co/docs/datasets/v2.10.0/en/package_reference/main_classes#datasets.Dataset.map).

# %%
from typing import Dict, List

def map_example(example: Dict[str, str]) -> Dict[str, List[int]]:
    # TODO: Tokenize the source and target text for an entry in the parallel dataset
    # and return a dictionary with the keys "encoder_input_ids" and "decoder_input_ids".
    # You can use `source_tokenizer` and `target_tokenizer`

    '''
    parameter: dictionary with keys "text_en" and "text_fr"
    return: dictionary with keys "encoder_input_ids" and "decoder_input_ids"
    '''

    source_tokenized_example = source_tokenizer(example['text_fr'])
    target_tokenized_example = target_tokenizer(example['text_en'])

    tokenized_example: Dict[str, List[int]] = {
        "encoder_input_ids": source_tokenized_example["input_ids"],
        "decoder_input_ids": target_tokenized_example["input_ids"],
    }

    return tokenized_example

# When mapped is applied to the DatasetDict object, it will apply `map` separately to each split.
tokenized_datasets = raw_text_datasets.map(map_example, batched=False)

# The `remove_columns` removes the existing text features from the new dataset, as they are no longer needed.
tokenized_datasets = tokenized_datasets.remove_columns(raw_text_datasets.column_names["train"])

# Sanity checks on the new dataset
assert set(tokenized_datasets.column_names["train"]) == {"decoder_input_ids", "encoder_input_ids"}
assert len(tokenized_datasets["train"]) == len(raw_text_datasets["train"])

# %% [markdown]
# ## Transformer model for NMT

# %% [markdown]
# We will now implement a encoder-decoder transformer model.
# We already provide code for the Feedforward Layers and Transformer Blocks, but you will have to implement the MultiHeadAttention and Embedding layer from scratch, as well as registering all the layers in the final EncoderDecoderModel. Pay attention to doc-strings and typing information to understand the context and purpose of each missing code block!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import math
from typing import Optional, Dict, List, Tuple

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self,
                 hidden_size: int,
                 num_attention_heads: int,
                 is_causal_attention: bool = False,
                 is_cross_attention: bool = False):
        """Defines a flexible multi-head attention layer.

        This layer should define parameters for the query, key and value projections, as well as the output projection,
        and implement the following steps:
        (1) Project the input vectors using query projection and key projection matrices.
        (2) Compute the head-wise attention scores scaled by 1/sqrt(head_dim)
        (3) Perform appropriate masking to the attention scores using key_padding_mask and optionally causal attention.
        (4) Normalize the head-wise attention scores using softmax.
        (5) Compute the value projections and then aggregate using the normalized attention scores.
        (6) Use the output projection to obtain the final output vectors.
        When is_cross_attention is True, the key and value projections are computed from the encoder outputs.
        Note that we do not use attention weight dropout in this implementation.

        Args:
            hidden_size: The dimensionality of the input vectors.
            num_attention_heads: The number of attention heads.
            is_causal_attention: Whether to use causal masking,
                    where tokens cannot attend to the future tokens on their right.
            is_cross_attention: Whether to use cross attention,
                    where we use different inputs for the key/value vs. query vectors.
        """
        super().__init__()
        assert hidden_size % num_attention_heads == 0, "The hidden size must be divisible by the number of attention heads."
        self.head_dim = hidden_size // num_attention_heads  # embedding dimension of query and key vectors per head

        # TODO Initialize the module and its parameters here.
        # This module should be able to handle both full self-attention, causal masked self-attention and cross-attention.
        # IMPORTANT: You are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!

        self.value_layer = nn.Linear(hidden_size, hidden_size)
        self.query_layer = nn.Linear(hidden_size, hidden_size)
        self.key_layer = nn.Linear(hidden_size, hidden_size)
        self.output_layer = nn.Linear(hidden_size, hidden_size)

        self.is_causal_attention = is_causal_attention
        self.is_cross_attention = is_cross_attention

    def causal_attention_mask(self,
                              sequence_length: int,
                              device: Optional[torch.device] = None) -> torch.FloatTensor:
        """Return a Float tensor that can be added to the (un-normalized) attention scores for causal masking.

        Args:
            sequence_length: width and height of the attention mask tensor.
            device: which torch device the resulting tensor should be on (important if you use GPU).

        Returns:
            A Float tensor of shape (1, 1, sequence_length, sequence_length) on device `device`,
            where the entries above the diagonal contain large negative values,
            which means that a query at position i can't attend to a key at position j>i.
        """


        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops.
        #
        # Hint 1: You can pick an arbitrary large value (e.g., -10^{6}), but note that
        #         using `float("-inf")` might lead to numerical issues and 'nan' values during training.
        #
        # Hint 2: Useful pytorch functions for this are `torch.arange` or `torch.triu`.
        #
        # Hint 3: You can move the tensor you create to a device by calling `tensor.to(device)`
        #
        # You should use this function in `forward` and use the returned tensor to implement causal masking
        # by adding it to the un-normalized attention scores of shape (batch_size, num_heads, sequence_length, sequence_length),
        # as torch will handle broadcasting and expand the first two dimensions to batch size and num_heads.
        #
        # You will the masking tensor to be on the same device as the attention scores's device,
        # which you can via the attribute `tensor.device`.
        mask = torch.triu(torch.ones((sequence_length, sequence_length), device=device) * float('-inf'), diagonal=1).unsqueeze(0).unsqueeze(0)
        return mask

    def forward(self,
                hidden_states: torch.FloatTensor,
                key_padding_mask: torch.BoolTensor,
                encoder_outputs: Optional[torch.FloatTensor] = None) -> Tuple[torch.FloatTensor, torch.FloatTensor]:
        """Computes scaled dot-product attention and returns the output of the attention layer.

        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the input vectors to the layer.
            key_padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
                    In the case of cross-attention, the tensor has shape (batch_size, encoder_sequence_length).
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size).
                    The output vectors of the encoder and only passed if the layer performs cross-attention.

        Returns:
            A (layer_output, attention_weights) where layer_output is a tensor of shape (batch_size, sequence_length, hidden_size)
            and attention_weights are the normalized attention scores in the form of
            a tensor of shape (batch_size, num_attention_heads, number_of_query_tokens, number_of_key_tokens).
        """

        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops. Furthermore,
        #            you are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!
        #
        # Hint 1: Use `torch.reshape` to add a new axis for the attention head,
        #         which will allow you to process all attention heads in parallel.
        #
        # Hint 2: You can use `torch.transpose` to swap the order of two axes,
        #         As the attention head dimension should be next to the batch size,
        #         see the shape of the output attention weights.
        #
        # Hint 3: `torch.bmm(matrix1, matrix2)` is useful for computing batched matrix multiplications
        #         If matrix1 has shape (B, M, N) and matrix2 has shape (1, B, N, P),
        #         it performs `B` matrix multiplications and outputs a tensor of shape (B, M, P).
        #         Alternatively, `torch.einsum` should be very useful.
        #         (We really encourage you to check out the documentation of `torch.einsum`,
        #         it can really make your life easier here.)

        batch_size, sequence_length, hidden_size = hidden_states.size()
        num_attention_heads = hidden_size // self.head_dim

        if self.is_cross_attention and encoder_outputs is not None:
            key_value_states = encoder_outputs
            key_padding_mask = key_padding_mask[:, :encoder_outputs.size(1)]
        else:
            key_value_states = hidden_states

        # apply the query, key and value layers
        queries = self.query_layer(hidden_states)
        keys = self.key_layer(key_value_states)
        values = self.value_layer(key_value_states)

        queries = queries.view(batch_size, sequence_length, num_attention_heads, self.head_dim).transpose(1, 2)
        keys = keys.view(batch_size, -1, num_attention_heads, self.head_dim).transpose(1, 2)
        values = values.view(batch_size, -1, num_attention_heads, self.head_dim).transpose(1, 2)

        # compute the attention scores
        attention_scores = torch.einsum("bhqd, bhkd -> bhqk", queries, keys) / math.sqrt(self.head_dim)
            # where b is the batch size, n is the number of attention heads, q is the number of query tokens, k is the number of key tokens

        # size of attention_scores: (batch_size, num_attention_heads, sequence_length, sequence_length)
        # apply the mask by broadcasting (batch_size, 1, 1, sequence_length) to (batch_size, num_attention_heads, sequence_length, sequence_length)
        if key_padding_mask is not None:
            attention_scores = attention_scores.masked_fill(key_padding_mask.unsqueeze(1).unsqueeze(2), float('-inf'))

        # differentiate between [masked and non-masked] attention -> early multi-head attentions in [encoder, decoder]
        if self.is_causal_attention:
            attention_scores = attention_scores + self.causal_attention_mask(sequence_length, device=hidden_states.device)


        # normalize the attention scores
        attention_scores = F.softmax(attention_scores, dim=-1)

        # apply the attention scores to the values
        # values shape: (batch_size, num_attention_heads, sequence_length, head_dim)
        # attention_scores shape: (batch_size, num_attention_heads, sequence_length, sequence_length)
        # attention_output shape: (batch_size, num_attention_heads, sequence_length, head_dim)
        attention_output = torch.einsum("bhqk, bhkd -> bhqd", attention_scores, values) # TODO: need test

        # concatenate the heads
        attention_output = attention_output.transpose(1, 2).contiguous().view(batch_size, sequence_length, hidden_size)

        # apply the output layer
        layer_output = self.output_layer(attention_output)

        # attention weights (batch_size, num_attention_heads, number_of_query_tokens, number_of_key_tokens) # TODO: need test
        return layer_output, attention_scores

# %% [markdown]
# Before we move on to the other modules, you should implement a sanity check for your attention implementation:
# 1. We check the dimensions of the output of the layer and
# 2. We plot the attention weights to some toy embedding inputs.
# We assume that the last token in the encoder and the last two tokens in the decoder are pad tokens.

# %%
embed_dim = 8
num_heads = 2
batch_size = 1
encoder_seq_length = 5
decoder_seq_length = 7

encoder_outputs = torch.randn(batch_size, encoder_seq_length, embed_dim)
decoder_inputs = torch.randn(batch_size, decoder_seq_length, embed_dim)

encoder_padding_mask = torch.zeros(batch_size, encoder_seq_length, dtype=torch.bool)
encoder_padding_mask[:, -1] = True # The last encoder token is a padding tokens

decoder_padding_mask = torch.zeros(batch_size, decoder_seq_length, dtype=torch.bool)
decoder_padding_mask[:, -2:] = True # The last two decoder tokens are padding token


cross_attention = MultiHeadAttention(embed_dim, num_heads, is_cross_attention=True)
causal_attention = MultiHeadAttention(embed_dim, num_heads, is_causal_attention=True)

cross_attention_out, cross_attention_weights = cross_attention(decoder_inputs, encoder_padding_mask, encoder_outputs)
causal_attention_out, causal_attention_weights = causal_attention(decoder_inputs, decoder_padding_mask)

# Make sure your outputs have the right hapes
assert cross_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert cross_attention_weights.shape == (batch_size, num_heads, decoder_seq_length, encoder_seq_length)
assert causal_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert causal_attention_weights.shape == (batch_size, num_heads, decoder_seq_length, decoder_seq_length)

# Check that the attention weights are normalized
assert torch.isclose(cross_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()
assert torch.isclose(causal_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()

# Check if the attention masking works
assert torch.isclose(cross_attention_weights[:,:,:,-1], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:,:,:,-2:], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:,:,2,3:], torch.tensor(0.0)).all()


import matplotlib.pyplot as plt
import numpy as np

def plot_attention_matrix(attention_matrix, title): # TODO: need test
    """Creates a new figure and plots the normalized attention weights as a heatmap.

    This should provide a colorbar for the scale of the heatmap and label the axes "query token position" and "key token position".

    Args:
        attention_matrix: A numpy array of shape (number_of_query_tokens, number_of_key_tokens)
        title: The title of the plot.
    """
    plt.figure(figsize=(8, 6))
    plt.imshow(attention_matrix, cmap='viridis', aspect='auto')
    plt.colorbar(label='Attention Score')
    plt.title(title)
    plt.xlabel('Key Token Position')
    plt.ylabel('Query Token Position')
    plt.xticks(ticks=np.arange(attention_matrix.shape[1]))
    plt.yticks(ticks=np.arange(attention_matrix.shape[0]))
    plt.show()

# # Example usage:
# # Assuming attention_scores is a tensor from the previous example
# # Convert it to a numpy array for plotting
# attention_matrix = attention_scores[0, 0].detach().numpy()  # Select the first batch and head
# plot_attention_matrix(attention_matrix, "Attention Weights Heatmap")

plot_attention_matrix(cross_attention_weights[0,0].detach().numpy(), "cross-attention, head 1")
plot_attention_matrix(cross_attention_weights[0,1].detach().numpy(), "cross-attention, head 2")
plot_attention_matrix(causal_attention_weights[0,0].detach().numpy(), "causal self-attention, head 1")
plot_attention_matrix(causal_attention_weights[0,1].detach().numpy(), "causal self-attention, head 2")

# %% [markdown]
# ## Embedding Layer

# %%
class TransformerEmbeddings(nn.Module):
    def __init__(self, vocab_size: int, hidden_size: int, max_sequence_length: int):
        """Defines the embedding layer with learnt positional embeddings.

        This layer defines both the token embeddings and positional embeddings,
        which are added together to form the final embedding.

        Args:
            vocab_size: The size of the vocabulary,
                    used to define the size of the token embedding table.
            hidden_size: The dimensionality of the embedding space for both token embeddings and positional embeddings.
            max_sequence_length: The maximum sequence length of the input sequences,
                    used to define the size of the position embedding table.

        Note that this implementation does not use dropout on the embeddings
        and uses learnt positional embeddings instead of sinusoidal embeddings.
        """
        super().__init__()

        # TODO Initialize the module and its parameters here.
        # You should use `nn.Embedding` for both token embeddings and positional embeddings
        self.token_embedding = nn.Embedding(vocab_size, hidden_size)
        self.positional_embedding = nn.Embedding(max_sequence_length, hidden_size)
        self.max_sequence_length = max_sequence_length

    def compute_logits(self, decoder_output: torch.FloatTensor) -> torch.FloatTensor:
        """Computes the logits for the next token prediction given the decoder output.

        Args:
            decoder_output: Tensor of shape (batch_size, sequence_length, hidden_size) - the output of the decoder.

        Returns:
            Tensor of shape (batch_size, sequence_length, vocab_size) containing the logits for the next token prediction.
        """

        # TODO Implement this function
        # Hint: you can access the weight parameter matrix via .weight of an nn.Embedding module:
        # Example:
        # ```embeddings = nn.Embedding(num_embeddings, embedding_dim)
        # assert list(embeddings.weight.shape) == [num_embeddings, embedding_dim]```
        # torch.matmul or F.linear may also be useful here.

        # (batch_size, sequence_length, hidden_size) * (hidden_size, vocab_size) = (batch_size, sequence_length, vocab_size)
        return torch.matmul(decoder_output, self.token_embedding.weight.T)

    def forward(self, input_ids: torch.LongTensor) -> torch.FloatTensor:
        """Computes the embeddings for the input tokens.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids.

        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing
                    the sum of token embeddings and position embeddings for the input tokens.
        """

        # TODO Implement the forward pass of the embedding layer.
        # IMPORTANT: For full credit, you should not use python loops!

        batch_size, sequence_length = input_ids.shape

        # compute the token embeddings
        token_embeddings = self.token_embedding(input_ids)  # shape: (batch_size, sequence_length, hidden_size)

        # create a positional embedding tensor
        positions = torch.arange(sequence_length, device=input_ids.device).unsqueeze(0) # shape: (1, sequence_length)
        positional_embedding = self.positional_embedding(positions) # shape: (1, sequence_length, hidden_size)

        total_embeddings = token_embeddings + positional_embedding # shape: (batch_size, sequence_length, hidden_size)

        return total_embeddings

# %%
class TransformerBlock(nn.Module):
    def __init__(self,
                 hidden_size: int,
                 intermediate_size: int,
                 num_attention_heads: int,
                 hidden_dropout_prob: float,
                 is_decoder: bool = False):
        """Defines a single Transformer block, which can be either for the encoder or the decoder.

        Args:
            hidden_size: The dimensionality of the input and output vectors of this layer.
            intermediate_size: The intermediate size of the feedforward layers.
            num_attention_heads: The number of attention heads.
            hidden_dropout_prob: The dropout probability for the hidden states.
            is_decoder: Whether this block is part of the decoder.
        """
        super().__init__()

        self.is_decoder = is_decoder
        self.self_attention = MultiHeadAttention(hidden_size, num_attention_heads, is_causal_attention=is_decoder)
        self.self_attention_layer_norm = nn.LayerNorm(hidden_size)

        if is_decoder:
            self.cross_attention = MultiHeadAttention(hidden_size, num_attention_heads, is_cross_attention=True)
            self.cross_attention_layer_norm = nn.LayerNorm(hidden_size)

        self.feedforward = nn.Sequential(
            nn.Linear(hidden_size, intermediate_size),
            nn.ReLU(),
            nn.Linear(intermediate_size, hidden_size),
            nn.Dropout(hidden_dropout_prob))
        self.feedforward_layer_norm = nn.LayerNorm(hidden_size)

    def forward(self,
                hidden_states: torch.FloatTensor,
                padding_mask: torch.BoolTensor,
                encoder_outputs: Optional[torch.FloatTensor] = None,
                encoder_padding_mask: Optional[torch.BoolTensor] = None) -> torch.FloatTensor:
        """Defines a single Transformer block, either for the encoder or the decoder.

        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the outputs from the previous layer.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size),
                    which are the output vectors of the encoder. This argument is only used by decoder blocks.
            encoder_padding_mask: Optional tensor of shape (batch_size, encoder_sequence_length) indicating
                    which encoder tokens are padding tokens. This argument is only used in decoder blocks.
                    A `True` entry means that this token should be ignored for the purpose of attention.

        """
        hidden_states = self.self_attention(hidden_states, padding_mask)[0] + hidden_states
        hidden_states = self.self_attention_layer_norm(hidden_states)

        if self.is_decoder:
            hidden_states = self.cross_attention(hidden_states, encoder_padding_mask, encoder_outputs)[0] + hidden_states
            hidden_states = self.cross_attention_layer_norm(hidden_states)

        hidden_states = self.feedforward(hidden_states) + hidden_states
        hidden_states = self.feedforward_layer_norm(hidden_states)
        return hidden_states

# %%
class EncoderDecoderModel(nn.Module):
    def __init__(self,
                 source_vocab_size: int,
                 target_vocab_size: int,
                 hidden_size: int,
                 intermediate_size: int,
                 num_attention_heads: int,
                 num_encoder_layers: int,
                 num_decoder_layers: int,
                 max_sequence_length: int,
                 hidden_dropout_prob: float):
        """A encoder-decoder transformer model which can be used for NMT.

        Args:
            source_vocab_size: The size of the source vocabulary.
            target_vocab_size: The size of the target vocabulary.
            hidden_size: The dimensionality of all input and output embeddings.
            intermediate_size: The intermediate size in the feedforward layers.
            num_attention_heads: The number of attention heads in each multi-head attention modules.
            num_encoder_layers: The number of transformer blocks in the encoder.
            num_decoder_layers: The number of transformer blocks in the decoder.
            max_sequence_length: The maximum sequence length that this model can handle.
            hidden_dropout_prob: The dropout probability in the hidden state in each block.
        """

        super().__init__()
        # TODO Register the input embedding modules and the encoder and decoder blocks.
        # You should use the TransformerBlock and TransformerEmbeddings sub-modules.
        #
        # Hint: Check out `nn.ModuleList` to register a variable number of sub-modules.

        self.source_embeddings = TransformerEmbeddings(source_vocab_size, hidden_size, max_sequence_length)
        self.target_embeddings = TransformerEmbeddings(target_vocab_size, hidden_size, max_sequence_length)
        self.transformer_encoders = nn.ModuleList([TransformerBlock(hidden_size, intermediate_size, num_attention_heads, hidden_dropout_prob) for _ in range(num_encoder_layers)])
        self.transformer_decoders = nn.ModuleList([TransformerBlock(hidden_size, intermediate_size, num_attention_heads, hidden_dropout_prob, is_decoder=True) for _ in range(num_decoder_layers)])
        self.num_encoder_layers = num_encoder_layers
    def forward_encoder(self, input_ids: torch.LongTensor, padding_mask: torch.BoolTensor) -> torch.FloatTensor:
        """Implement the forward pass of the encoder.

        Args:
            input_ids: tensor of shape (batch_size, sequence_length) containing the input token ids to the encoder.
            padding_mask: tensor of shape (batch_size, sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.

        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing the output embeddings of the encoder.
        """

        # TODO Implement this function
        embedding = self.source_embeddings(input_ids)

        transformerBlockInput = embedding
        transformerBlockOutput = None
        for block in self.transformer_encoders:
            transformerBlockOutput = block(transformerBlockInput, padding_mask)
            transformerBlockInput = transformerBlockOutput

        return transformerBlockOutput
    def forward_decoder(self,
                        input_ids: torch.LongTensor,
                        padding_mask: torch.BoolTensor,
                        encoder_outputs: torch.FloatTensor,
                        encoder_padding_mask: torch.BoolTensor) -> torch.FloatTensor:
        """Implement the forward pass of the decoder.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids to the decoder.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which decoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.
            encoder_outputs: Tensor of shape (batch_size, encoder_sequence_length, hidden_size) containing the output embeddings of the encoder.
            encoder_padding_mask: Tensor of shape (batch_size, encoder_sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in cross-attention computations.

        Returns:
            Tensor of shape (batch_size, sequence_length, target_vocabulary_size)
            containing the logits for predicting the next token in the target sequence.
        """

        # TODO Implement this function
        embedding = self.target_embeddings(input_ids)

        transformerBlockInput = embedding
        transformerBlockOutput = None
        for block in self.transformer_decoders:
            transformerBlockOutput = block(transformerBlockInput, padding_mask, encoder_outputs, encoder_padding_mask)
            transformerBlockInput = transformerBlockOutput

        return self.target_embeddings.compute_logits(transformerBlockOutput)

    def forward(self, encoder_input_ids, encoder_padding_mask, decoder_input_ids, decoder_padding_mask):
        encoder_outputs = self.forward_encoder(encoder_input_ids, encoder_padding_mask)
        decoder_logits = self.forward_decoder(decoder_input_ids, decoder_padding_mask, encoder_outputs, encoder_padding_mask)
        return decoder_logits

# %% [markdown]
# ## Train the model
#
# In this section, we train the seq2seq model on the parallel tokenized corpus.
# Before you start training models, you should implement and test the model and its sub-modules, especially the attention.
#
# First, we implement a `collate` function, which takes a list of examples from the dataset and forms a batch,
# consisting of padded encoder and decoder input ids, as well as encoder and decoder padding masks.

# %%
def collate_fn(examples: List[Dict[str, List[int]]]) -> Dict[str, torch.Tensor]:
    """Collates a list of variable length sequences from the dataset into a batch of pytorch tensors with padding."""

    encoder_sequence_length = max(len(example["encoder_input_ids"]) for example in examples)
    decoder_sequence_length = max(len(example["decoder_input_ids"]) for example in examples)
    batch_size = len(examples)

    encoder_input_ids = torch.full((batch_size, encoder_sequence_length),
                                   fill_value=source_tokenizer.pad_token_id,
                                   dtype=torch.int64)
    encoder_padding_mask = torch.ones((batch_size, encoder_sequence_length),
                                      dtype=torch.bool)

    decoder_input_ids = torch.full((batch_size, decoder_sequence_length),
                                   fill_value=target_tokenizer.pad_token_id,
                                   dtype=torch.int64)
    decoder_padding_mask = torch.ones((batch_size, decoder_sequence_length),
                                      dtype=torch.bool)

    for i, example in enumerate(examples):
        encoder_input_ids[i, :len(example["encoder_input_ids"])] = torch.tensor(example["encoder_input_ids"])
        encoder_padding_mask[i, :len(example["encoder_input_ids"])] = False

        decoder_input_ids[i, :len(example["decoder_input_ids"])] = torch.tensor(example["decoder_input_ids"])
        decoder_padding_mask[i, :len(example["decoder_input_ids"])] = False

    return {"encoder_input_ids": encoder_input_ids,
            "encoder_padding_mask": encoder_padding_mask,
            "decoder_input_ids": decoder_input_ids,
            "decoder_padding_mask": decoder_padding_mask}

# %% [markdown]
# Next, we provide a simple training loop.

# %%
import time
import math

def compute_loss_per_token(model, batch):
    logits = model(**batch)

    valid_label_mask = ~(batch["decoder_padding_mask"][:,1:])
    labels = batch["decoder_input_ids"][:,1:][valid_label_mask]
    logits = logits[:,:-1][valid_label_mask]

    return F.cross_entropy(logits, labels, reduction='none')


def evaluate_perplexity(model, dataset, batch_size=32, device="cpu"):
    model.eval()

    dev_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

    num_tokens = loss_sum = 0

    # no_grad() signals backend to throw away all gradients
    with torch.no_grad():
        for batch in dev_loader:
            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)

            token_losses = compute_loss_per_token(model, batch)

            loss_sum += token_losses.sum()
            num_tokens += token_losses.numel()

        dev_ppl = (loss_sum / num_tokens).exp().cpu().item()
    return dev_ppl


def train(model, training_dataset, validation_dataset,
          batch_size=32, lr=1e-3, max_epoch=10, log_every=10, valid_niter=100,
          model_path="model.pt"):
    model.train()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Use device: %s' % device)

    model = model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    epoch = global_step = loss_sum = num_tokens = num_examples = 0
    best_valid_perplexity = float('inf')
    train_time = begin_time = time.time()
    print('Beginning maximum likelihood training')


    while True:
        train_loader = torch.utils.data.DataLoader(
            training_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
        epoch += 1
        batches_per_epoch = len(train_loader)
        for i, batch in enumerate(train_loader):
            global_step += 1

            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)

            optimizer.zero_grad()

            token_losses = compute_loss_per_token(model, batch)
            total_loss = token_losses.sum()

            loss = total_loss / batch_size
            loss.backward()

            optimizer.step()

            loss_sum += total_loss.cpu().item()
            num_tokens += token_losses.numel()
            num_examples += batch_size

            if global_step % log_every == 0:
                average_loss = loss_sum / num_examples
                average_ppl = math.exp(loss_sum / num_tokens)
                print(f"epoch {epoch} ({i}/{batches_per_epoch}) | step {global_step} | "
                      f"avg_nll={average_loss:.2f} avg_ppl={average_ppl:.2f} "
                      f"speed={num_tokens / (time.time() - train_time):.2f} words/sec "
                      f"time_elapsed={time.time() - begin_time:.2f} sec")

                train_time = time.time()
                loss_sum = num_tokens = num_examples = 0.0

            if global_step % valid_niter == 0:
                print('Begin validation ...')
                dev_perplexity = evaluate_perplexity(model, validation_dataset, batch_size=batch_size, device=device)

                print(f"validation: step {global_step} | dev_ppl={dev_perplexity}")

                if dev_perplexity < best_valid_perplexity:
                    best_valid_perplexity = dev_perplexity
                    print(f"epoch {epoch} step {global_step}: save currently the best model to '{model_path}'")
                    torch.save(model.state_dict(), model_path)
                    torch.save(optimizer.state_dict(), model_path + '.optim')
                model.train()

        if epoch == max_epoch:
            print('Reached maximum number of epochs')
            break

# %% [markdown]
# Let's train a relatively small model architecture for 15 epochs.
# With a reasonable implementation, this should take about 16 minutes on CPU / 3 minutes on GPU and we should achieve a validation perplexity of below 10!

# %%
# Set a random seed, so you obtain the same output model if you run this cell again.
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

model = EncoderDecoderModel(
    source_vocab_size=source_tokenizer.vocab_size,
    target_vocab_size=target_tokenizer.vocab_size,
    hidden_size=32,
    intermediate_size=32 * 4,
    num_attention_heads=4,
    num_encoder_layers=3,
    num_decoder_layers=3,
    max_sequence_length=32,
    hidden_dropout_prob=0.1,
    )

print("Model architecture:", model)
print("Total number of trainable model parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))

train(model, tokenized_datasets["train"], tokenized_datasets["validation"],
      max_epoch=15, model_path="model.pt")
# Out:
# Model architecture: EncoderDecoderModel(
#   (source_embeddings): TransformerEmbeddings(
#     (token_embedding): Embedding(3200, 32)
#     (positional_embedding): Embedding(32, 32)
#   )
#   (target_embeddings): TransformerEmbeddings(
#     (token_embedding): Embedding(3200, 32)
#     (positional_embedding): Embedding(32, 32)
#   )
#   (transformer_encoders): ModuleList(
#     (0-2): 3 x TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (value_layer): Linear(in_features=32, out_features=32, bias=True)
#         (query_layer): Linear(in_features=32, out_features=32, bias=True)
#         (key_layer): Linear(in_features=32, out_features=32, bias=True)
#         (output_layer): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (transformer_decoders): ModuleList(
#     (0-2): 3 x TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (value_layer): Linear(in_features=32, out_features=32, bias=True)
#         (query_layer): Linear(in_features=32, out_features=32, bias=True)
#         (key_layer): Linear(in_features=32, out_features=32, bias=True)
#         (output_layer): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (cross_attention): MultiHeadAttention(
#         (value_layer): Linear(in_features=32, out_features=32, bias=True)
#         (query_layer): Linear(in_features=32, out_features=32, bias=True)
#         (key_layer): Linear(in_features=32, out_features=32, bias=True)
#         (output_layer): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (cross_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
# )
# Total number of trainable model parameters: 295936
# Use device: cuda
# Beginning maximum likelihood training
# epoch 1 (9/272) | step 10 | avg_nll=123.95 avg_ppl=24198869.05 speed=5437.70 words/sec time_elapsed=0.43 sec
# epoch 1 (19/272) | step 20 | avg_nll=85.39 avg_ppl=158574.97 speed=5210.39 words/sec time_elapsed=0.87 sec
# epoch 1 (29/272) | step 30 | avg_nll=78.04 avg_ppl=55778.57 speed=5401.23 words/sec time_elapsed=1.29 sec
# epoch 1 (39/272) | step 40 | avg_nll=73.68 avg_ppl=25680.49 speed=5400.61 words/sec time_elapsed=1.72 sec
# epoch 1 (49/272) | step 50 | avg_nll=68.88 avg_ppl=11659.41 speed=3831.38 words/sec time_elapsed=2.33 sec
# epoch 1 (59/272) | step 60 | avg_nll=63.60 avg_ppl=5498.64 speed=3049.62 words/sec time_elapsed=3.11 sec
# epoch 1 (69/272) | step 70 | avg_nll=55.84 avg_ppl=2350.26 speed=7371.26 words/sec time_elapsed=3.42 sec
# epoch 1 (79/272) | step 80 | avg_nll=52.16 avg_ppl=1336.78 speed=5976.90 words/sec time_elapsed=3.81 sec
# epoch 1 (89/272) | step 90 | avg_nll=50.05 avg_ppl=1010.67 speed=6162.48 words/sec time_elapsed=4.19 sec
# epoch 1 (99/272) | step 100 | avg_nll=46.95 avg_ppl=661.73 speed=6116.07 words/sec time_elapsed=4.57 sec
# Begin validation ...
# validation: step 100 | dev_ppl=442.4314880371094
# epoch 1 step 100: save currently the best model to 'model.pt'
# epoch 1 (109/272) | step 110 | avg_nll=44.73 avg_ppl=485.86 speed=3410.74 words/sec time_elapsed=5.25 sec
# epoch 1 (119/272) | step 120 | avg_nll=43.45 avg_ppl=399.83 speed=5599.11 words/sec time_elapsed=5.66 sec
# epoch 1 (129/272) | step 130 | avg_nll=43.03 avg_ppl=354.18 speed=5203.46 words/sec time_elapsed=6.11 sec
# epoch 1 (139/272) | step 140 | avg_nll=39.23 avg_ppl=244.34 speed=6264.29 words/sec time_elapsed=6.48 sec
# epoch 1 (149/272) | step 150 | avg_nll=38.22 avg_ppl=209.07 speed=8545.19 words/sec time_elapsed=6.74 sec
# epoch 1 (159/272) | step 160 | avg_nll=37.27 avg_ppl=181.88 speed=8379.46 words/sec time_elapsed=7.02 sec
# epoch 1 (169/272) | step 170 | avg_nll=34.80 avg_ppl=137.14 speed=8510.65 words/sec time_elapsed=7.28 sec
# epoch 1 (179/272) | step 180 | avg_nll=35.78 avg_ppl=138.84 speed=8460.21 words/sec time_elapsed=7.56 sec
# epoch 1 (189/272) | step 190 | avg_nll=34.02 avg_ppl=115.75 speed=8442.33 words/sec time_elapsed=7.83 sec
# epoch 1 (199/272) | step 200 | avg_nll=33.87 avg_ppl=107.92 speed=8204.23 words/sec time_elapsed=8.11 sec
# Begin validation ...
# validation: step 200 | dev_ppl=96.29167175292969
# epoch 1 step 200: save currently the best model to 'model.pt'
# epoch 1 (209/272) | step 210 | avg_nll=35.28 avg_ppl=113.87 speed=5148.23 words/sec time_elapsed=8.58 sec
# epoch 1 (219/272) | step 220 | avg_nll=33.83 avg_ppl=107.38 speed=8594.76 words/sec time_elapsed=8.84 sec
# epoch 1 (229/272) | step 230 | avg_nll=33.40 avg_ppl=96.44 speed=8368.94 words/sec time_elapsed=9.12 sec
# epoch 1 (239/272) | step 240 | avg_nll=33.30 avg_ppl=93.29 speed=8755.56 words/sec time_elapsed=9.39 sec
# epoch 1 (249/272) | step 250 | avg_nll=33.20 avg_ppl=92.33 speed=8454.66 words/sec time_elapsed=9.67 sec
# epoch 1 (259/272) | step 260 | avg_nll=30.98 avg_ppl=72.94 speed=7755.20 words/sec time_elapsed=9.97 sec
# epoch 1 (269/272) | step 270 | avg_nll=30.17 avg_ppl=65.92 speed=8606.86 words/sec time_elapsed=10.24 sec
# epoch 2 (7/272) | step 280 | avg_nll=28.63 avg_ppl=56.79 speed=8289.54 words/sec time_elapsed=10.51 sec
# epoch 2 (17/272) | step 290 | avg_nll=29.80 avg_ppl=62.53 speed=8668.22 words/sec time_elapsed=10.78 sec
# epoch 2 (27/272) | step 300 | avg_nll=29.41 avg_ppl=58.38 speed=8296.00 words/sec time_elapsed=11.06 sec
# Begin validation ...
# validation: step 300 | dev_ppl=52.89736557006836
# epoch 2 step 300: save currently the best model to 'model.pt'
# epoch 2 (37/272) | step 310 | avg_nll=29.20 avg_ppl=56.78 speed=5031.76 words/sec time_elapsed=11.51 sec
# epoch 2 (47/272) | step 320 | avg_nll=28.69 avg_ppl=52.58 speed=8690.38 words/sec time_elapsed=11.78 sec
# epoch 2 (57/272) | step 330 | avg_nll=27.44 avg_ppl=45.13 speed=8248.74 words/sec time_elapsed=12.06 sec
# epoch 2 (67/272) | step 340 | avg_nll=28.59 avg_ppl=50.41 speed=8801.95 words/sec time_elapsed=12.33 sec
# epoch 2 (77/272) | step 350 | avg_nll=28.75 avg_ppl=50.12 speed=8687.88 words/sec time_elapsed=12.60 sec
# epoch 2 (87/272) | step 360 | avg_nll=28.03 avg_ppl=48.81 speed=8330.54 words/sec time_elapsed=12.87 sec
# epoch 2 (97/272) | step 370 | avg_nll=28.46 avg_ppl=46.75 speed=8503.92 words/sec time_elapsed=13.15 sec
# epoch 2 (107/272) | step 380 | avg_nll=26.68 avg_ppl=40.94 speed=8659.69 words/sec time_elapsed=13.42 sec
# epoch 2 (117/272) | step 390 | avg_nll=25.84 avg_ppl=37.97 speed=8450.10 words/sec time_elapsed=13.69 sec
# epoch 2 (127/272) | step 400 | avg_nll=24.68 avg_ppl=34.27 speed=8193.08 words/sec time_elapsed=13.96 sec
# Begin validation ...
# validation: step 400 | dev_ppl=37.678707122802734
# epoch 2 step 400: save currently the best model to 'model.pt'
# epoch 2 (137/272) | step 410 | avg_nll=26.61 avg_ppl=38.81 speed=4989.28 words/sec time_elapsed=14.43 sec
# epoch 2 (147/272) | step 420 | avg_nll=28.40 avg_ppl=46.22 speed=8748.14 words/sec time_elapsed=14.70 sec
# epoch 2 (157/272) | step 430 | avg_nll=25.60 avg_ppl=35.38 speed=8555.33 words/sec time_elapsed=14.97 sec
# epoch 2 (167/272) | step 440 | avg_nll=26.44 avg_ppl=37.11 speed=8421.60 words/sec time_elapsed=15.24 sec
# epoch 2 (177/272) | step 450 | avg_nll=27.23 avg_ppl=39.97 speed=8722.08 words/sec time_elapsed=15.52 sec
# epoch 2 (187/272) | step 460 | avg_nll=25.29 avg_ppl=33.22 speed=8447.08 words/sec time_elapsed=15.79 sec
# epoch 2 (197/272) | step 470 | avg_nll=24.62 avg_ppl=30.71 speed=8533.36 words/sec time_elapsed=16.06 sec
# epoch 2 (207/272) | step 480 | avg_nll=24.95 avg_ppl=32.17 speed=8368.93 words/sec time_elapsed=16.33 sec
# epoch 2 (217/272) | step 490 | avg_nll=25.06 avg_ppl=32.38 speed=5965.01 words/sec time_elapsed=16.72 sec
# epoch 2 (227/272) | step 500 | avg_nll=25.86 avg_ppl=33.95 speed=6247.56 words/sec time_elapsed=17.10 sec
# Begin validation ...
# validation: step 500 | dev_ppl=29.663536071777344
# epoch 2 step 500: save currently the best model to 'model.pt'
# epoch 2 (237/272) | step 510 | avg_nll=26.47 avg_ppl=37.10 speed=3814.95 words/sec time_elapsed=17.71 sec
# epoch 2 (247/272) | step 520 | avg_nll=24.71 avg_ppl=31.16 speed=5608.18 words/sec time_elapsed=18.12 sec
# epoch 2 (257/272) | step 530 | avg_nll=24.96 avg_ppl=32.41 speed=5294.13 words/sec time_elapsed=18.56 sec
# epoch 2 (267/272) | step 540 | avg_nll=25.28 avg_ppl=31.69 speed=5806.08 words/sec time_elapsed=18.96 sec
# epoch 3 (5/272) | step 550 | avg_nll=24.10 avg_ppl=27.55 speed=5270.57 words/sec time_elapsed=19.40 sec
# epoch 3 (15/272) | step 560 | avg_nll=25.14 avg_ppl=30.77 speed=8402.01 words/sec time_elapsed=19.68 sec
# epoch 3 (25/272) | step 570 | avg_nll=23.80 avg_ppl=26.71 speed=8686.40 words/sec time_elapsed=19.95 sec
# epoch 3 (35/272) | step 580 | avg_nll=23.81 avg_ppl=26.52 speed=8154.33 words/sec time_elapsed=20.23 sec
# epoch 3 (45/272) | step 590 | avg_nll=23.17 avg_ppl=25.50 speed=8103.15 words/sec time_elapsed=20.52 sec
# epoch 3 (55/272) | step 600 | avg_nll=23.91 avg_ppl=27.57 speed=8780.32 words/sec time_elapsed=20.78 sec
# Begin validation ...
# validation: step 600 | dev_ppl=25.405885696411133
# epoch 3 step 600: save currently the best model to 'model.pt'
# epoch 3 (65/272) | step 610 | avg_nll=23.83 avg_ppl=26.29 speed=5038.20 words/sec time_elapsed=21.24 sec
# epoch 3 (75/272) | step 620 | avg_nll=22.79 avg_ppl=25.31 speed=7963.10 words/sec time_elapsed=21.53 sec
# epoch 3 (85/272) | step 630 | avg_nll=23.22 avg_ppl=24.65 speed=8419.39 words/sec time_elapsed=21.80 sec
# epoch 3 (95/272) | step 640 | avg_nll=23.37 avg_ppl=24.92 speed=8680.71 words/sec time_elapsed=22.07 sec
# epoch 3 (105/272) | step 650 | avg_nll=23.88 avg_ppl=25.52 speed=8642.75 words/sec time_elapsed=22.34 sec
# epoch 3 (115/272) | step 660 | avg_nll=23.27 avg_ppl=25.18 speed=8332.02 words/sec time_elapsed=22.62 sec
# epoch 3 (125/272) | step 670 | avg_nll=22.38 avg_ppl=23.06 speed=7824.15 words/sec time_elapsed=22.91 sec
# epoch 3 (135/272) | step 680 | avg_nll=23.96 avg_ppl=26.26 speed=8879.18 words/sec time_elapsed=23.18 sec
# epoch 3 (145/272) | step 690 | avg_nll=24.08 avg_ppl=26.96 speed=8261.41 words/sec time_elapsed=23.46 sec
# epoch 3 (155/272) | step 700 | avg_nll=23.84 avg_ppl=25.77 speed=8436.70 words/sec time_elapsed=23.74 sec
# Begin validation ...
# validation: step 700 | dev_ppl=23.247488021850586
# epoch 3 step 700: save currently the best model to 'model.pt'
# epoch 3 (165/272) | step 710 | avg_nll=23.16 avg_ppl=24.11 speed=5032.67 words/sec time_elapsed=24.20 sec
# epoch 3 (175/272) | step 720 | avg_nll=22.81 avg_ppl=22.86 speed=8154.48 words/sec time_elapsed=24.49 sec
# epoch 3 (185/272) | step 730 | avg_nll=22.28 avg_ppl=21.72 speed=8727.13 words/sec time_elapsed=24.75 sec
# epoch 3 (195/272) | step 740 | avg_nll=21.73 avg_ppl=20.80 speed=8581.55 words/sec time_elapsed=25.02 sec
# epoch 3 (205/272) | step 750 | avg_nll=22.47 avg_ppl=22.59 speed=8426.83 words/sec time_elapsed=25.29 sec
# epoch 3 (215/272) | step 760 | avg_nll=22.45 avg_ppl=21.99 speed=8181.73 words/sec time_elapsed=25.58 sec
# epoch 3 (225/272) | step 770 | avg_nll=21.40 avg_ppl=19.26 speed=8738.29 words/sec time_elapsed=25.84 sec
# epoch 3 (235/272) | step 780 | avg_nll=22.72 avg_ppl=23.31 speed=8436.72 words/sec time_elapsed=26.12 sec
# epoch 3 (245/272) | step 790 | avg_nll=21.78 avg_ppl=21.20 speed=8327.69 words/sec time_elapsed=26.39 sec
# epoch 3 (255/272) | step 800 | avg_nll=21.49 avg_ppl=20.19 speed=8205.54 words/sec time_elapsed=26.67 sec
# Begin validation ...
# validation: step 800 | dev_ppl=20.385141372680664
# epoch 3 step 800: save currently the best model to 'model.pt'
# epoch 3 (265/272) | step 810 | avg_nll=22.98 avg_ppl=22.55 speed=5166.17 words/sec time_elapsed=27.13 sec
# epoch 4 (3/272) | step 820 | avg_nll=21.24 avg_ppl=19.16 speed=8606.42 words/sec time_elapsed=27.40 sec
# epoch 4 (13/272) | step 830 | avg_nll=20.99 avg_ppl=18.59 speed=8100.49 words/sec time_elapsed=27.68 sec
# epoch 4 (23/272) | step 840 | avg_nll=21.55 avg_ppl=19.18 speed=8698.78 words/sec time_elapsed=27.95 sec
# epoch 4 (33/272) | step 850 | avg_nll=21.63 avg_ppl=19.96 speed=8593.46 words/sec time_elapsed=28.22 sec
# epoch 4 (43/272) | step 860 | avg_nll=21.38 avg_ppl=19.31 speed=8226.87 words/sec time_elapsed=28.50 sec
# epoch 4 (53/272) | step 870 | avg_nll=21.03 avg_ppl=18.58 speed=8562.26 words/sec time_elapsed=28.77 sec
# epoch 4 (63/272) | step 880 | avg_nll=22.01 avg_ppl=20.30 speed=8828.60 words/sec time_elapsed=29.03 sec
# epoch 4 (73/272) | step 890 | avg_nll=21.54 avg_ppl=19.19 speed=8759.59 words/sec time_elapsed=29.30 sec
# epoch 4 (83/272) | step 900 | avg_nll=21.83 avg_ppl=19.94 speed=6489.98 words/sec time_elapsed=29.66 sec
# Begin validation ...
# validation: step 900 | dev_ppl=19.023393630981445
# epoch 4 step 900: save currently the best model to 'model.pt'
# epoch 4 (93/272) | step 910 | avg_nll=21.15 avg_ppl=18.34 speed=3628.87 words/sec time_elapsed=30.30 sec
# epoch 4 (103/272) | step 920 | avg_nll=21.35 avg_ppl=19.56 speed=5808.71 words/sec time_elapsed=30.70 sec
# epoch 4 (113/272) | step 930 | avg_nll=20.89 avg_ppl=18.39 speed=5600.56 words/sec time_elapsed=31.11 sec
# epoch 4 (123/272) | step 940 | avg_nll=21.37 avg_ppl=18.73 speed=5517.36 words/sec time_elapsed=31.53 sec
# epoch 4 (133/272) | step 950 | avg_nll=21.41 avg_ppl=19.11 speed=5481.08 words/sec time_elapsed=31.95 sec
# epoch 4 (143/272) | step 960 | avg_nll=21.45 avg_ppl=18.66 speed=5607.01 words/sec time_elapsed=32.37 sec
# epoch 4 (153/272) | step 970 | avg_nll=21.23 avg_ppl=18.69 speed=7232.73 words/sec time_elapsed=32.70 sec
# epoch 4 (163/272) | step 980 | avg_nll=22.49 avg_ppl=21.28 speed=8641.60 words/sec time_elapsed=32.97 sec
# epoch 4 (173/272) | step 990 | avg_nll=20.39 avg_ppl=17.47 speed=8412.57 words/sec time_elapsed=33.24 sec
# epoch 4 (183/272) | step 1000 | avg_nll=21.05 avg_ppl=18.34 speed=8475.23 words/sec time_elapsed=33.51 sec
# Begin validation ...
# validation: step 1000 | dev_ppl=18.793296813964844
# epoch 4 step 1000: save currently the best model to 'model.pt'
# epoch 4 (193/272) | step 1010 | avg_nll=20.95 avg_ppl=17.90 speed=4953.74 words/sec time_elapsed=33.98 sec
# epoch 4 (203/272) | step 1020 | avg_nll=20.90 avg_ppl=17.88 speed=8796.01 words/sec time_elapsed=34.24 sec
# epoch 4 (213/272) | step 1030 | avg_nll=20.75 avg_ppl=17.76 speed=8821.14 words/sec time_elapsed=34.51 sec
# epoch 4 (223/272) | step 1040 | avg_nll=20.44 avg_ppl=17.46 speed=8104.64 words/sec time_elapsed=34.79 sec
# epoch 4 (233/272) | step 1050 | avg_nll=21.61 avg_ppl=19.59 speed=8686.46 words/sec time_elapsed=35.06 sec
# epoch 4 (243/272) | step 1060 | avg_nll=20.46 avg_ppl=16.98 speed=8658.47 words/sec time_elapsed=35.32 sec
# epoch 4 (253/272) | step 1070 | avg_nll=20.41 avg_ppl=16.59 speed=8548.95 words/sec time_elapsed=35.60 sec
# epoch 4 (263/272) | step 1080 | avg_nll=20.05 avg_ppl=16.76 speed=8242.55 words/sec time_elapsed=35.87 sec
# epoch 5 (1/272) | step 1090 | avg_nll=20.92 avg_ppl=18.08 speed=8499.74 words/sec time_elapsed=36.14 sec
# epoch 5 (11/272) | step 1100 | avg_nll=21.05 avg_ppl=17.93 speed=8878.44 words/sec time_elapsed=36.41 sec
# Begin validation ...
# validation: step 1100 | dev_ppl=16.974164962768555
# epoch 5 step 1100: save currently the best model to 'model.pt'
# epoch 5 (21/272) | step 1110 | avg_nll=18.39 avg_ppl=13.78 speed=4762.78 words/sec time_elapsed=36.88 sec
# epoch 5 (31/272) | step 1120 | avg_nll=19.78 avg_ppl=15.41 speed=8626.28 words/sec time_elapsed=37.15 sec
# epoch 5 (41/272) | step 1130 | avg_nll=20.65 avg_ppl=16.46 speed=9143.82 words/sec time_elapsed=37.40 sec
# epoch 5 (51/272) | step 1140 | avg_nll=20.47 avg_ppl=16.31 speed=8893.62 words/sec time_elapsed=37.67 sec
# epoch 5 (61/272) | step 1150 | avg_nll=20.44 avg_ppl=16.39 speed=8644.18 words/sec time_elapsed=37.94 sec
# epoch 5 (71/272) | step 1160 | avg_nll=20.06 avg_ppl=16.39 speed=8600.89 words/sec time_elapsed=38.21 sec
# epoch 5 (81/272) | step 1170 | avg_nll=20.36 avg_ppl=16.49 speed=8613.93 words/sec time_elapsed=38.48 sec
# epoch 5 (91/272) | step 1180 | avg_nll=20.34 avg_ppl=16.21 speed=8669.54 words/sec time_elapsed=38.75 sec
# epoch 5 (101/272) | step 1190 | avg_nll=20.87 avg_ppl=16.91 speed=8387.89 words/sec time_elapsed=39.03 sec
# epoch 5 (111/272) | step 1200 | avg_nll=20.11 avg_ppl=16.03 speed=8703.43 words/sec time_elapsed=39.29 sec
# Begin validation ...
# validation: step 1200 | dev_ppl=16.344655990600586
# epoch 5 step 1200: save currently the best model to 'model.pt'
# epoch 5 (121/272) | step 1210 | avg_nll=20.15 avg_ppl=15.85 speed=4989.39 words/sec time_elapsed=39.76 sec
# epoch 5 (131/272) | step 1220 | avg_nll=19.69 avg_ppl=15.46 speed=7870.68 words/sec time_elapsed=40.05 sec
# epoch 5 (141/272) | step 1230 | avg_nll=20.00 avg_ppl=16.22 speed=8611.14 words/sec time_elapsed=40.32 sec
# epoch 5 (151/272) | step 1240 | avg_nll=20.24 avg_ppl=16.47 speed=8579.62 words/sec time_elapsed=40.59 sec
# epoch 5 (161/272) | step 1250 | avg_nll=20.52 avg_ppl=16.76 speed=7977.91 words/sec time_elapsed=40.88 sec
# epoch 5 (171/272) | step 1260 | avg_nll=19.18 avg_ppl=14.06 speed=8752.61 words/sec time_elapsed=41.15 sec
# epoch 5 (181/272) | step 1270 | avg_nll=18.77 avg_ppl=14.08 speed=8626.27 words/sec time_elapsed=41.41 sec
# epoch 5 (191/272) | step 1280 | avg_nll=19.69 avg_ppl=15.95 speed=7567.14 words/sec time_elapsed=41.71 sec
# epoch 5 (201/272) | step 1290 | avg_nll=19.57 avg_ppl=15.56 speed=7808.26 words/sec time_elapsed=42.00 sec
# epoch 5 (211/272) | step 1300 | avg_nll=20.29 avg_ppl=15.82 speed=8756.29 words/sec time_elapsed=42.27 sec
# Begin validation ...
# validation: step 1300 | dev_ppl=15.559154510498047
# epoch 5 step 1300: save currently the best model to 'model.pt'
# epoch 5 (221/272) | step 1310 | avg_nll=19.56 avg_ppl=14.85 speed=3958.85 words/sec time_elapsed=42.86 sec
# epoch 5 (231/272) | step 1320 | avg_nll=18.57 avg_ppl=13.42 speed=5314.23 words/sec time_elapsed=43.29 sec
# epoch 5 (241/272) | step 1330 | avg_nll=20.72 avg_ppl=16.44 speed=6460.82 words/sec time_elapsed=43.66 sec
# epoch 5 (251/272) | step 1340 | avg_nll=19.26 avg_ppl=14.50 speed=5679.16 words/sec time_elapsed=44.06 sec
# epoch 5 (261/272) | step 1350 | avg_nll=18.52 avg_ppl=13.70 speed=5320.57 words/sec time_elapsed=44.49 sec
# epoch 5 (271/272) | step 1360 | avg_nll=20.51 avg_ppl=16.16 speed=5620.11 words/sec time_elapsed=44.91 sec
# epoch 6 (9/272) | step 1370 | avg_nll=19.55 avg_ppl=14.77 speed=5426.20 words/sec time_elapsed=45.34 sec
# epoch 6 (19/272) | step 1380 | avg_nll=18.54 avg_ppl=13.27 speed=6868.00 words/sec time_elapsed=45.67 sec
# epoch 6 (29/272) | step 1390 | avg_nll=19.29 avg_ppl=13.84 speed=8382.51 words/sec time_elapsed=45.95 sec
# epoch 6 (39/272) | step 1400 | avg_nll=19.37 avg_ppl=14.10 speed=8432.54 words/sec time_elapsed=46.23 sec
# Begin validation ...
# validation: step 1400 | dev_ppl=15.146733283996582
# epoch 6 step 1400: save currently the best model to 'model.pt'
# epoch 6 (49/272) | step 1410 | avg_nll=19.06 avg_ppl=13.96 speed=5039.52 words/sec time_elapsed=46.69 sec
# epoch 6 (59/272) | step 1420 | avg_nll=17.98 avg_ppl=12.63 speed=8253.85 words/sec time_elapsed=46.96 sec
# epoch 6 (69/272) | step 1430 | avg_nll=19.02 avg_ppl=13.66 speed=8303.22 words/sec time_elapsed=47.25 sec
# epoch 6 (79/272) | step 1440 | avg_nll=20.33 avg_ppl=15.51 speed=8769.28 words/sec time_elapsed=47.52 sec
# epoch 6 (89/272) | step 1450 | avg_nll=18.78 avg_ppl=13.18 speed=8514.10 words/sec time_elapsed=47.79 sec
# epoch 6 (99/272) | step 1460 | avg_nll=18.57 avg_ppl=13.37 speed=8572.13 words/sec time_elapsed=48.06 sec
# epoch 6 (109/272) | step 1470 | avg_nll=18.92 avg_ppl=13.91 speed=8414.28 words/sec time_elapsed=48.33 sec
# epoch 6 (119/272) | step 1480 | avg_nll=18.96 avg_ppl=13.61 speed=8543.28 words/sec time_elapsed=48.60 sec
# epoch 6 (129/272) | step 1490 | avg_nll=18.40 avg_ppl=13.02 speed=8352.96 words/sec time_elapsed=48.88 sec
# epoch 6 (139/272) | step 1500 | avg_nll=18.51 avg_ppl=13.20 speed=8142.94 words/sec time_elapsed=49.16 sec
# Begin validation ...
# validation: step 1500 | dev_ppl=14.514473915100098
# epoch 6 step 1500: save currently the best model to 'model.pt'
# epoch 6 (149/272) | step 1510 | avg_nll=19.52 avg_ppl=14.26 speed=5170.70 words/sec time_elapsed=49.61 sec
# epoch 6 (159/272) | step 1520 | avg_nll=19.78 avg_ppl=15.34 speed=8539.82 words/sec time_elapsed=49.89 sec
# epoch 6 (169/272) | step 1530 | avg_nll=19.38 avg_ppl=14.48 speed=8203.23 words/sec time_elapsed=50.17 sec
# epoch 6 (179/272) | step 1540 | avg_nll=19.05 avg_ppl=13.94 speed=8720.51 words/sec time_elapsed=50.43 sec
# epoch 6 (189/272) | step 1550 | avg_nll=18.86 avg_ppl=13.39 speed=8476.18 words/sec time_elapsed=50.71 sec
# epoch 6 (199/272) | step 1560 | avg_nll=19.56 avg_ppl=14.47 speed=8410.15 words/sec time_elapsed=50.99 sec
# epoch 6 (209/272) | step 1570 | avg_nll=19.09 avg_ppl=14.02 speed=8222.76 words/sec time_elapsed=51.27 sec
# epoch 6 (219/272) | step 1580 | avg_nll=18.22 avg_ppl=12.36 speed=8451.76 words/sec time_elapsed=51.54 sec
# epoch 6 (229/272) | step 1590 | avg_nll=17.96 avg_ppl=12.08 speed=8526.15 words/sec time_elapsed=51.81 sec
# epoch 6 (239/272) | step 1600 | avg_nll=19.63 avg_ppl=14.11 speed=8774.19 words/sec time_elapsed=52.08 sec
# Begin validation ...
# validation: step 1600 | dev_ppl=14.046858787536621
# epoch 6 step 1600: save currently the best model to 'model.pt'
# epoch 6 (249/272) | step 1610 | avg_nll=17.43 avg_ppl=11.68 speed=4827.20 words/sec time_elapsed=52.55 sec
# epoch 6 (259/272) | step 1620 | avg_nll=18.15 avg_ppl=12.73 speed=7550.90 words/sec time_elapsed=52.86 sec
# epoch 6 (269/272) | step 1630 | avg_nll=19.32 avg_ppl=14.59 speed=8544.11 words/sec time_elapsed=53.13 sec
# epoch 7 (7/272) | step 1640 | avg_nll=18.10 avg_ppl=12.45 speed=8131.11 words/sec time_elapsed=53.41 sec
# epoch 7 (17/272) | step 1650 | avg_nll=19.06 avg_ppl=13.46 speed=8498.64 words/sec time_elapsed=53.69 sec
# epoch 7 (27/272) | step 1660 | avg_nll=18.95 avg_ppl=13.83 speed=8624.18 words/sec time_elapsed=53.95 sec
# epoch 7 (37/272) | step 1670 | avg_nll=18.82 avg_ppl=12.98 speed=8930.06 words/sec time_elapsed=54.22 sec
# epoch 7 (47/272) | step 1680 | avg_nll=17.39 avg_ppl=10.96 speed=8200.95 words/sec time_elapsed=54.50 sec
# epoch 7 (57/272) | step 1690 | avg_nll=18.36 avg_ppl=12.69 speed=8508.63 words/sec time_elapsed=54.77 sec
# epoch 7 (67/272) | step 1700 | avg_nll=17.54 avg_ppl=11.11 speed=8655.46 words/sec time_elapsed=55.04 sec
# Begin validation ...
# validation: step 1700 | dev_ppl=13.464231491088867
# epoch 7 step 1700: save currently the best model to 'model.pt'
# epoch 7 (77/272) | step 1710 | avg_nll=18.24 avg_ppl=12.60 speed=4798.51 words/sec time_elapsed=55.52 sec
# epoch 7 (87/272) | step 1720 | avg_nll=16.92 avg_ppl=10.81 speed=5595.18 words/sec time_elapsed=55.93 sec
# epoch 7 (97/272) | step 1730 | avg_nll=18.26 avg_ppl=13.06 speed=6037.66 words/sec time_elapsed=56.31 sec
# epoch 7 (107/272) | step 1740 | avg_nll=18.94 avg_ppl=13.24 speed=6493.32 words/sec time_elapsed=56.67 sec
# epoch 7 (117/272) | step 1750 | avg_nll=17.60 avg_ppl=11.27 speed=5805.40 words/sec time_elapsed=57.07 sec
# epoch 7 (127/272) | step 1760 | avg_nll=18.36 avg_ppl=12.55 speed=5471.35 words/sec time_elapsed=57.50 sec
# epoch 7 (137/272) | step 1770 | avg_nll=18.09 avg_ppl=12.23 speed=5103.09 words/sec time_elapsed=57.95 sec
# epoch 7 (147/272) | step 1780 | avg_nll=18.34 avg_ppl=12.30 speed=8030.49 words/sec time_elapsed=58.24 sec
# epoch 7 (157/272) | step 1790 | avg_nll=18.19 avg_ppl=12.49 speed=8301.09 words/sec time_elapsed=58.52 sec
# epoch 7 (167/272) | step 1800 | avg_nll=16.42 avg_ppl=10.33 speed=8400.17 words/sec time_elapsed=58.79 sec
# Begin validation ...
# validation: step 1800 | dev_ppl=13.159249305725098
# epoch 7 step 1800: save currently the best model to 'model.pt'
# epoch 7 (177/272) | step 1810 | avg_nll=18.35 avg_ppl=12.72 speed=5059.97 words/sec time_elapsed=59.25 sec
# epoch 7 (187/272) | step 1820 | avg_nll=17.78 avg_ppl=11.78 speed=8304.75 words/sec time_elapsed=59.52 sec
# epoch 7 (197/272) | step 1830 | avg_nll=19.21 avg_ppl=13.47 speed=8731.75 words/sec time_elapsed=59.79 sec
# epoch 7 (207/272) | step 1840 | avg_nll=17.80 avg_ppl=11.63 speed=8664.15 words/sec time_elapsed=60.06 sec
# epoch 7 (217/272) | step 1850 | avg_nll=18.30 avg_ppl=12.05 speed=7910.32 words/sec time_elapsed=60.36 sec
# epoch 7 (227/272) | step 1860 | avg_nll=18.00 avg_ppl=11.74 speed=8036.73 words/sec time_elapsed=60.65 sec
# epoch 7 (237/272) | step 1870 | avg_nll=18.42 avg_ppl=12.28 speed=8564.77 words/sec time_elapsed=60.93 sec
# epoch 7 (247/272) | step 1880 | avg_nll=17.85 avg_ppl=12.13 speed=8615.71 words/sec time_elapsed=61.19 sec
# epoch 7 (257/272) | step 1890 | avg_nll=18.22 avg_ppl=12.10 speed=7827.76 words/sec time_elapsed=61.49 sec
# epoch 7 (267/272) | step 1900 | avg_nll=16.85 avg_ppl=10.54 speed=8388.76 words/sec time_elapsed=61.76 sec
# Begin validation ...
# validation: step 1900 | dev_ppl=12.81845760345459
# epoch 7 step 1900: save currently the best model to 'model.pt'
# epoch 8 (5/272) | step 1910 | avg_nll=16.96 avg_ppl=10.90 speed=4971.53 words/sec time_elapsed=62.22 sec
# epoch 8 (15/272) | step 1920 | avg_nll=17.17 avg_ppl=10.68 speed=8437.11 words/sec time_elapsed=62.49 sec
# epoch 8 (25/272) | step 1930 | avg_nll=17.07 avg_ppl=10.54 speed=8333.59 words/sec time_elapsed=62.77 sec
# epoch 8 (35/272) | step 1940 | avg_nll=17.68 avg_ppl=11.54 speed=8702.22 words/sec time_elapsed=63.04 sec
# epoch 8 (45/272) | step 1950 | avg_nll=17.20 avg_ppl=10.59 speed=8460.73 words/sec time_elapsed=63.32 sec
# epoch 8 (55/272) | step 1960 | avg_nll=16.76 avg_ppl=10.59 speed=7862.02 words/sec time_elapsed=63.60 sec
# epoch 8 (65/272) | step 1970 | avg_nll=16.11 avg_ppl=9.38 speed=8423.19 words/sec time_elapsed=63.88 sec
# epoch 8 (75/272) | step 1980 | avg_nll=17.23 avg_ppl=11.02 speed=8246.41 words/sec time_elapsed=64.16 sec
# epoch 8 (85/272) | step 1990 | avg_nll=17.29 avg_ppl=10.69 speed=8812.51 words/sec time_elapsed=64.42 sec
# epoch 8 (95/272) | step 2000 | avg_nll=17.16 avg_ppl=10.91 speed=8013.16 words/sec time_elapsed=64.71 sec
# Begin validation ...
# validation: step 2000 | dev_ppl=12.61619758605957
# epoch 8 step 2000: save currently the best model to 'model.pt'
# epoch 8 (105/272) | step 2010 | avg_nll=17.05 avg_ppl=10.64 speed=5017.11 words/sec time_elapsed=65.17 sec
# epoch 8 (115/272) | step 2020 | avg_nll=17.41 avg_ppl=10.98 speed=8684.43 words/sec time_elapsed=65.44 sec
# epoch 8 (125/272) | step 2030 | avg_nll=17.58 avg_ppl=10.82 speed=5875.03 words/sec time_elapsed=65.84 sec
# epoch 8 (135/272) | step 2040 | avg_nll=17.90 avg_ppl=11.85 speed=8636.36 words/sec time_elapsed=66.11 sec
# epoch 8 (145/272) | step 2050 | avg_nll=17.59 avg_ppl=11.39 speed=8714.22 words/sec time_elapsed=66.37 sec
# epoch 8 (155/272) | step 2060 | avg_nll=17.93 avg_ppl=11.08 speed=8445.21 words/sec time_elapsed=66.66 sec
# epoch 8 (165/272) | step 2070 | avg_nll=16.47 avg_ppl=9.89 speed=8463.28 words/sec time_elapsed=66.93 sec
# epoch 8 (175/272) | step 2080 | avg_nll=17.86 avg_ppl=11.28 speed=8787.90 words/sec time_elapsed=67.20 sec
# epoch 8 (185/272) | step 2090 | avg_nll=18.01 avg_ppl=11.99 speed=8484.81 words/sec time_elapsed=67.47 sec
# epoch 8 (195/272) | step 2100 | avg_nll=16.85 avg_ppl=10.57 speed=8061.96 words/sec time_elapsed=67.75 sec
# Begin validation ...
# validation: step 2100 | dev_ppl=12.240781784057617
# epoch 8 step 2100: save currently the best model to 'model.pt'
# epoch 8 (205/272) | step 2110 | avg_nll=18.05 avg_ppl=11.94 speed=4026.90 words/sec time_elapsed=68.33 sec
# epoch 8 (215/272) | step 2120 | avg_nll=17.06 avg_ppl=10.68 speed=5809.56 words/sec time_elapsed=68.73 sec
# epoch 8 (225/272) | step 2130 | avg_nll=16.69 avg_ppl=10.14 speed=6283.53 words/sec time_elapsed=69.10 sec
# epoch 8 (235/272) | step 2140 | avg_nll=16.32 avg_ppl=10.09 speed=5824.37 words/sec time_elapsed=69.49 sec
# epoch 8 (245/272) | step 2150 | avg_nll=16.79 avg_ppl=10.20 speed=5412.66 words/sec time_elapsed=69.91 sec
# epoch 8 (255/272) | step 2160 | avg_nll=17.80 avg_ppl=11.45 speed=5776.48 words/sec time_elapsed=70.32 sec
# epoch 8 (265/272) | step 2170 | avg_nll=17.84 avg_ppl=11.64 speed=5319.45 words/sec time_elapsed=70.76 sec
# epoch 9 (3/272) | step 2180 | avg_nll=16.95 avg_ppl=10.47 speed=7363.77 words/sec time_elapsed=71.07 sec
# epoch 9 (13/272) | step 2190 | avg_nll=16.42 avg_ppl=9.76 speed=8656.69 words/sec time_elapsed=71.34 sec
# epoch 9 (23/272) | step 2200 | avg_nll=16.23 avg_ppl=9.45 speed=8191.07 words/sec time_elapsed=71.62 sec
# Begin validation ...
# validation: step 2200 | dev_ppl=12.46837043762207
# epoch 9 (33/272) | step 2210 | avg_nll=16.21 avg_ppl=9.65 speed=5310.33 words/sec time_elapsed=72.05 sec
# epoch 9 (43/272) | step 2220 | avg_nll=17.05 avg_ppl=10.33 speed=8724.45 words/sec time_elapsed=72.32 sec
# epoch 9 (53/272) | step 2230 | avg_nll=17.00 avg_ppl=10.51 speed=8596.60 words/sec time_elapsed=72.59 sec
# epoch 9 (63/272) | step 2240 | avg_nll=16.98 avg_ppl=10.22 speed=8645.50 words/sec time_elapsed=72.86 sec
# epoch 9 (73/272) | step 2250 | avg_nll=16.75 avg_ppl=9.83 speed=8474.76 words/sec time_elapsed=73.14 sec
# epoch 9 (83/272) | step 2260 | avg_nll=16.61 avg_ppl=9.86 speed=8791.68 words/sec time_elapsed=73.40 sec
# epoch 9 (93/272) | step 2270 | avg_nll=17.20 avg_ppl=10.72 speed=8502.30 words/sec time_elapsed=73.67 sec
# epoch 9 (103/272) | step 2280 | avg_nll=16.02 avg_ppl=9.35 speed=8090.47 words/sec time_elapsed=73.96 sec
# epoch 9 (113/272) | step 2290 | avg_nll=16.32 avg_ppl=9.94 speed=8493.19 words/sec time_elapsed=74.23 sec
# epoch 9 (123/272) | step 2300 | avg_nll=17.17 avg_ppl=10.29 speed=8690.80 words/sec time_elapsed=74.50 sec
# Begin validation ...
# validation: step 2300 | dev_ppl=11.460258483886719
# epoch 9 step 2300: save currently the best model to 'model.pt'
# epoch 9 (133/272) | step 2310 | avg_nll=16.50 avg_ppl=10.03 speed=4825.12 words/sec time_elapsed=74.97 sec
# epoch 9 (143/272) | step 2320 | avg_nll=16.12 avg_ppl=9.37 speed=8592.75 words/sec time_elapsed=75.24 sec
# epoch 9 (153/272) | step 2330 | avg_nll=17.17 avg_ppl=10.56 speed=8723.94 words/sec time_elapsed=75.51 sec
# epoch 9 (163/272) | step 2340 | avg_nll=16.32 avg_ppl=9.65 speed=8595.96 words/sec time_elapsed=75.77 sec
# epoch 9 (173/272) | step 2350 | avg_nll=17.34 avg_ppl=10.74 speed=8326.96 words/sec time_elapsed=76.06 sec
# epoch 9 (183/272) | step 2360 | avg_nll=16.44 avg_ppl=10.01 speed=8436.55 words/sec time_elapsed=76.33 sec
# epoch 9 (193/272) | step 2370 | avg_nll=15.85 avg_ppl=8.87 speed=8555.71 words/sec time_elapsed=76.60 sec
# epoch 9 (203/272) | step 2380 | avg_nll=16.52 avg_ppl=9.72 speed=8630.55 words/sec time_elapsed=76.87 sec
# epoch 9 (213/272) | step 2390 | avg_nll=17.20 avg_ppl=10.83 speed=8223.79 words/sec time_elapsed=77.15 sec
# epoch 9 (223/272) | step 2400 | avg_nll=16.80 avg_ppl=9.59 speed=8930.17 words/sec time_elapsed=77.41 sec
# Begin validation ...
# validation: step 2400 | dev_ppl=11.325721740722656
# epoch 9 step 2400: save currently the best model to 'model.pt'
# epoch 9 (233/272) | step 2410 | avg_nll=17.37 avg_ppl=10.81 speed=5060.58 words/sec time_elapsed=77.88 sec
# epoch 9 (243/272) | step 2420 | avg_nll=17.34 avg_ppl=10.86 speed=8252.63 words/sec time_elapsed=78.16 sec
# epoch 9 (253/272) | step 2430 | avg_nll=15.35 avg_ppl=8.60 speed=8445.73 words/sec time_elapsed=78.43 sec
# epoch 9 (263/272) | step 2440 | avg_nll=15.98 avg_ppl=8.87 speed=8505.90 words/sec time_elapsed=78.70 sec
# epoch 10 (1/272) | step 2450 | avg_nll=16.71 avg_ppl=10.34 speed=8264.85 words/sec time_elapsed=78.98 sec
# epoch 10 (11/272) | step 2460 | avg_nll=16.21 avg_ppl=9.41 speed=8302.92 words/sec time_elapsed=79.26 sec
# epoch 10 (21/272) | step 2470 | avg_nll=15.27 avg_ppl=8.48 speed=8640.91 words/sec time_elapsed=79.53 sec
# epoch 10 (31/272) | step 2480 | avg_nll=15.58 avg_ppl=8.69 speed=8650.39 words/sec time_elapsed=79.79 sec
# epoch 10 (41/272) | step 2490 | avg_nll=15.69 avg_ppl=8.85 speed=8120.67 words/sec time_elapsed=80.08 sec
# epoch 10 (51/272) | step 2500 | avg_nll=16.03 avg_ppl=8.95 speed=8521.09 words/sec time_elapsed=80.35 sec
# Begin validation ...
# validation: step 2500 | dev_ppl=11.164054870605469
# epoch 10 step 2500: save currently the best model to 'model.pt'
# epoch 10 (61/272) | step 2510 | avg_nll=16.25 avg_ppl=9.35 speed=5027.04 words/sec time_elapsed=80.81 sec
# epoch 10 (71/272) | step 2520 | avg_nll=16.22 avg_ppl=9.65 speed=5999.37 words/sec time_elapsed=81.19 sec
# epoch 10 (81/272) | step 2530 | avg_nll=15.74 avg_ppl=8.83 speed=6205.69 words/sec time_elapsed=81.57 sec
# epoch 10 (91/272) | step 2540 | avg_nll=15.11 avg_ppl=8.60 speed=5954.46 words/sec time_elapsed=81.95 sec
# epoch 10 (101/272) | step 2550 | avg_nll=16.95 avg_ppl=10.23 speed=6107.47 words/sec time_elapsed=82.33 sec
# epoch 10 (111/272) | step 2560 | avg_nll=15.11 avg_ppl=8.07 speed=5690.11 words/sec time_elapsed=82.74 sec
# epoch 10 (121/272) | step 2570 | avg_nll=17.30 avg_ppl=10.48 speed=5226.08 words/sec time_elapsed=83.19 sec
# epoch 10 (131/272) | step 2580 | avg_nll=14.61 avg_ppl=7.59 speed=5483.14 words/sec time_elapsed=83.61 sec
# epoch 10 (141/272) | step 2590 | avg_nll=16.87 avg_ppl=9.85 speed=5614.74 words/sec time_elapsed=84.03 sec
# epoch 10 (151/272) | step 2600 | avg_nll=15.70 avg_ppl=8.92 speed=8316.66 words/sec time_elapsed=84.31 sec
# Begin validation ...
# validation: step 2600 | dev_ppl=10.907418251037598
# epoch 10 step 2600: save currently the best model to 'model.pt'
# epoch 10 (161/272) | step 2610 | avg_nll=15.46 avg_ppl=8.29 speed=5084.01 words/sec time_elapsed=84.77 sec
# epoch 10 (171/272) | step 2620 | avg_nll=16.76 avg_ppl=9.80 speed=8762.63 words/sec time_elapsed=85.04 sec
# epoch 10 (181/272) | step 2630 | avg_nll=16.76 avg_ppl=9.54 speed=8622.40 words/sec time_elapsed=85.31 sec
# epoch 10 (191/272) | step 2640 | avg_nll=15.35 avg_ppl=8.52 speed=8517.65 words/sec time_elapsed=85.58 sec
# epoch 10 (201/272) | step 2650 | avg_nll=14.97 avg_ppl=8.09 speed=8488.42 words/sec time_elapsed=85.85 sec
# epoch 10 (211/272) | step 2660 | avg_nll=16.17 avg_ppl=9.20 speed=8497.46 words/sec time_elapsed=86.13 sec
# epoch 10 (221/272) | step 2670 | avg_nll=14.89 avg_ppl=8.10 speed=8290.25 words/sec time_elapsed=86.40 sec
# epoch 10 (231/272) | step 2680 | avg_nll=15.37 avg_ppl=8.26 speed=8604.04 words/sec time_elapsed=86.67 sec
# epoch 10 (241/272) | step 2690 | avg_nll=17.42 avg_ppl=10.31 speed=8783.14 words/sec time_elapsed=86.94 sec
# epoch 10 (251/272) | step 2700 | avg_nll=16.21 avg_ppl=9.37 speed=8572.63 words/sec time_elapsed=87.21 sec
# Begin validation ...
# validation: step 2700 | dev_ppl=10.723187446594238
# epoch 10 step 2700: save currently the best model to 'model.pt'
# epoch 10 (261/272) | step 2710 | avg_nll=15.78 avg_ppl=9.23 speed=4729.17 words/sec time_elapsed=87.69 sec
# epoch 10 (271/272) | step 2720 | avg_nll=14.96 avg_ppl=8.17 speed=8456.14 words/sec time_elapsed=87.96 sec
# epoch 11 (9/272) | step 2730 | avg_nll=14.24 avg_ppl=7.50 speed=8486.94 words/sec time_elapsed=88.23 sec
# epoch 11 (19/272) | step 2740 | avg_nll=14.54 avg_ppl=7.57 speed=8312.71 words/sec time_elapsed=88.51 sec
# epoch 11 (29/272) | step 2750 | avg_nll=15.56 avg_ppl=8.67 speed=8650.89 words/sec time_elapsed=88.77 sec
# epoch 11 (39/272) | step 2760 | avg_nll=14.73 avg_ppl=7.76 speed=8681.90 words/sec time_elapsed=89.04 sec
# epoch 11 (49/272) | step 2770 | avg_nll=16.42 avg_ppl=9.21 speed=8301.19 words/sec time_elapsed=89.32 sec
# epoch 11 (59/272) | step 2780 | avg_nll=16.08 avg_ppl=9.12 speed=8786.61 words/sec time_elapsed=89.59 sec
# epoch 11 (69/272) | step 2790 | avg_nll=14.83 avg_ppl=8.06 speed=8244.41 words/sec time_elapsed=89.86 sec
# epoch 11 (79/272) | step 2800 | avg_nll=15.74 avg_ppl=8.49 speed=8696.87 words/sec time_elapsed=90.14 sec
# Begin validation ...
# validation: step 2800 | dev_ppl=10.861902236938477
# epoch 11 (89/272) | step 2810 | avg_nll=15.72 avg_ppl=8.69 speed=5433.20 words/sec time_elapsed=90.56 sec
# epoch 11 (99/272) | step 2820 | avg_nll=13.86 avg_ppl=7.13 speed=8258.96 words/sec time_elapsed=90.84 sec
# epoch 11 (109/272) | step 2830 | avg_nll=15.50 avg_ppl=8.46 speed=8722.50 words/sec time_elapsed=91.10 sec
# epoch 11 (119/272) | step 2840 | avg_nll=15.94 avg_ppl=8.78 speed=8334.78 words/sec time_elapsed=91.39 sec
# epoch 11 (129/272) | step 2850 | avg_nll=14.90 avg_ppl=7.83 speed=8759.70 words/sec time_elapsed=91.65 sec
# epoch 11 (139/272) | step 2860 | avg_nll=15.88 avg_ppl=8.68 speed=8632.24 words/sec time_elapsed=91.92 sec
# epoch 11 (149/272) | step 2870 | avg_nll=15.27 avg_ppl=8.35 speed=8703.88 words/sec time_elapsed=92.19 sec
# epoch 11 (159/272) | step 2880 | avg_nll=14.79 avg_ppl=7.64 speed=8178.33 words/sec time_elapsed=92.47 sec
# epoch 11 (169/272) | step 2890 | avg_nll=14.29 avg_ppl=7.56 speed=8199.76 words/sec time_elapsed=92.75 sec
# epoch 11 (179/272) | step 2900 | avg_nll=15.96 avg_ppl=8.75 speed=8998.26 words/sec time_elapsed=93.01 sec
# Begin validation ...
# validation: step 2900 | dev_ppl=10.313735961914062
# epoch 11 step 2900: save currently the best model to 'model.pt'
# epoch 11 (189/272) | step 2910 | avg_nll=15.98 avg_ppl=8.87 speed=5001.11 words/sec time_elapsed=93.48 sec
# epoch 11 (199/272) | step 2920 | avg_nll=15.43 avg_ppl=8.58 speed=8159.38 words/sec time_elapsed=93.76 sec
# epoch 11 (209/272) | step 2930 | avg_nll=16.61 avg_ppl=9.40 speed=8438.59 words/sec time_elapsed=94.04 sec
# epoch 11 (219/272) | step 2940 | avg_nll=15.61 avg_ppl=8.50 speed=5637.88 words/sec time_elapsed=94.46 sec
# epoch 11 (229/272) | step 2950 | avg_nll=15.94 avg_ppl=8.75 speed=6334.88 words/sec time_elapsed=94.83 sec
# epoch 11 (239/272) | step 2960 | avg_nll=14.51 avg_ppl=7.47 speed=6498.50 words/sec time_elapsed=95.18 sec
# epoch 11 (249/272) | step 2970 | avg_nll=14.79 avg_ppl=7.55 speed=5865.02 words/sec time_elapsed=95.58 sec
# epoch 11 (259/272) | step 2980 | avg_nll=14.13 avg_ppl=7.27 speed=5434.29 words/sec time_elapsed=96.00 sec
# epoch 11 (269/272) | step 2990 | avg_nll=14.95 avg_ppl=8.23 speed=5572.94 words/sec time_elapsed=96.41 sec
# epoch 12 (7/272) | step 3000 | avg_nll=15.02 avg_ppl=8.11 speed=5086.44 words/sec time_elapsed=96.86 sec
# Begin validation ...
# validation: step 3000 | dev_ppl=10.184085845947266
# epoch 12 step 3000: save currently the best model to 'model.pt'
# epoch 12 (17/272) | step 3010 | avg_nll=13.35 avg_ppl=6.50 speed=4876.92 words/sec time_elapsed=97.33 sec
# epoch 12 (27/272) | step 3020 | avg_nll=13.88 avg_ppl=7.11 speed=8110.27 words/sec time_elapsed=97.61 sec
# epoch 12 (37/272) | step 3030 | avg_nll=14.15 avg_ppl=7.34 speed=8584.61 words/sec time_elapsed=97.88 sec
# epoch 12 (47/272) | step 3040 | avg_nll=14.18 avg_ppl=7.20 speed=8510.30 words/sec time_elapsed=98.15 sec
# epoch 12 (57/272) | step 3050 | avg_nll=13.73 avg_ppl=6.85 speed=8577.72 words/sec time_elapsed=98.41 sec
# epoch 12 (67/272) | step 3060 | avg_nll=15.19 avg_ppl=7.95 speed=8500.51 words/sec time_elapsed=98.69 sec
# epoch 12 (77/272) | step 3070 | avg_nll=15.32 avg_ppl=8.08 speed=8583.53 words/sec time_elapsed=98.96 sec
# epoch 12 (87/272) | step 3080 | avg_nll=14.17 avg_ppl=7.15 speed=8634.06 words/sec time_elapsed=99.23 sec
# epoch 12 (97/272) | step 3090 | avg_nll=15.56 avg_ppl=8.24 speed=8762.51 words/sec time_elapsed=99.50 sec
# epoch 12 (107/272) | step 3100 | avg_nll=14.46 avg_ppl=7.61 speed=8201.25 words/sec time_elapsed=99.78 sec
# Begin validation ...
# validation: step 3100 | dev_ppl=9.942283630371094
# epoch 12 step 3100: save currently the best model to 'model.pt'
# epoch 12 (117/272) | step 3110 | avg_nll=15.28 avg_ppl=8.23 speed=4988.68 words/sec time_elapsed=100.24 sec
# epoch 12 (127/272) | step 3120 | avg_nll=14.63 avg_ppl=7.54 speed=8516.36 words/sec time_elapsed=100.51 sec
# epoch 12 (137/272) | step 3130 | avg_nll=13.35 avg_ppl=6.52 speed=8247.61 words/sec time_elapsed=100.79 sec
# epoch 12 (147/272) | step 3140 | avg_nll=14.47 avg_ppl=7.25 speed=8723.52 words/sec time_elapsed=101.06 sec
# epoch 12 (157/272) | step 3150 | avg_nll=15.20 avg_ppl=8.02 speed=8686.76 words/sec time_elapsed=101.33 sec
# epoch 12 (167/272) | step 3160 | avg_nll=15.19 avg_ppl=8.13 speed=8455.02 words/sec time_elapsed=101.60 sec
# epoch 12 (177/272) | step 3170 | avg_nll=14.76 avg_ppl=7.59 speed=7708.79 words/sec time_elapsed=101.90 sec
# epoch 12 (187/272) | step 3180 | avg_nll=14.26 avg_ppl=7.14 speed=8637.84 words/sec time_elapsed=102.17 sec
# epoch 12 (197/272) | step 3190 | avg_nll=14.73 avg_ppl=7.64 speed=8753.88 words/sec time_elapsed=102.44 sec
# epoch 12 (207/272) | step 3200 | avg_nll=14.69 avg_ppl=7.40 speed=8329.12 words/sec time_elapsed=102.72 sec
# Begin validation ...
# validation: step 3200 | dev_ppl=10.004327774047852
# epoch 12 (217/272) | step 3210 | avg_nll=13.80 avg_ppl=6.74 speed=5386.77 words/sec time_elapsed=103.15 sec
# epoch 12 (227/272) | step 3220 | avg_nll=14.82 avg_ppl=7.64 speed=8684.95 words/sec time_elapsed=103.42 sec
# epoch 12 (237/272) | step 3230 | avg_nll=15.50 avg_ppl=8.24 speed=8718.71 words/sec time_elapsed=103.69 sec
# epoch 12 (247/272) | step 3240 | avg_nll=15.77 avg_ppl=8.67 speed=8021.71 words/sec time_elapsed=103.98 sec
# epoch 12 (257/272) | step 3250 | avg_nll=15.64 avg_ppl=8.22 speed=8804.80 words/sec time_elapsed=104.25 sec
# epoch 12 (267/272) | step 3260 | avg_nll=15.48 avg_ppl=8.49 speed=8756.53 words/sec time_elapsed=104.51 sec
# epoch 13 (5/272) | step 3270 | avg_nll=13.62 avg_ppl=6.74 speed=7902.08 words/sec time_elapsed=104.80 sec
# epoch 13 (15/272) | step 3280 | avg_nll=13.60 avg_ppl=6.54 speed=8497.03 words/sec time_elapsed=105.08 sec
# epoch 13 (25/272) | step 3290 | avg_nll=14.39 avg_ppl=7.48 speed=8539.66 words/sec time_elapsed=105.34 sec
# epoch 13 (35/272) | step 3300 | avg_nll=13.34 avg_ppl=6.31 speed=8269.66 words/sec time_elapsed=105.62 sec
# Begin validation ...
# validation: step 3300 | dev_ppl=9.992521286010742
# epoch 13 (45/272) | step 3310 | avg_nll=14.24 avg_ppl=7.15 speed=5391.89 words/sec time_elapsed=106.05 sec
# epoch 13 (55/272) | step 3320 | avg_nll=14.27 avg_ppl=7.27 speed=8660.43 words/sec time_elapsed=106.32 sec
# epoch 13 (65/272) | step 3330 | avg_nll=14.09 avg_ppl=6.94 speed=8726.01 words/sec time_elapsed=106.59 sec
# epoch 13 (75/272) | step 3340 | avg_nll=14.40 avg_ppl=7.06 speed=8468.02 words/sec time_elapsed=106.86 sec
# epoch 13 (85/272) | step 3350 | avg_nll=13.94 avg_ppl=7.05 speed=5770.73 words/sec time_elapsed=107.26 sec
# epoch 13 (95/272) | step 3360 | avg_nll=14.76 avg_ppl=7.62 speed=6344.60 words/sec time_elapsed=107.63 sec
# epoch 13 (105/272) | step 3370 | avg_nll=14.31 avg_ppl=7.17 speed=6215.09 words/sec time_elapsed=108.00 sec
# epoch 13 (115/272) | step 3380 | avg_nll=13.71 avg_ppl=6.61 speed=6000.86 words/sec time_elapsed=108.39 sec
# epoch 13 (125/272) | step 3390 | avg_nll=14.24 avg_ppl=7.07 speed=5612.30 words/sec time_elapsed=108.81 sec
# epoch 13 (135/272) | step 3400 | avg_nll=13.45 avg_ppl=6.33 speed=5279.68 words/sec time_elapsed=109.25 sec
# Begin validation ...
# validation: step 3400 | dev_ppl=10.176833152770996
# epoch 13 (145/272) | step 3410 | avg_nll=15.32 avg_ppl=7.85 speed=3857.91 words/sec time_elapsed=109.87 sec
# epoch 13 (155/272) | step 3420 | avg_nll=14.52 avg_ppl=7.62 speed=5471.71 words/sec time_elapsed=110.28 sec
# epoch 13 (165/272) | step 3430 | avg_nll=14.50 avg_ppl=7.24 speed=8760.23 words/sec time_elapsed=110.55 sec
# epoch 13 (175/272) | step 3440 | avg_nll=13.03 avg_ppl=6.20 speed=8562.10 words/sec time_elapsed=110.82 sec
# epoch 13 (185/272) | step 3450 | avg_nll=13.47 avg_ppl=6.42 speed=8147.23 words/sec time_elapsed=111.10 sec
# epoch 13 (195/272) | step 3460 | avg_nll=13.86 avg_ppl=7.07 speed=8462.12 words/sec time_elapsed=111.37 sec
# epoch 13 (205/272) | step 3470 | avg_nll=14.11 avg_ppl=7.08 speed=8534.65 words/sec time_elapsed=111.64 sec
# epoch 13 (215/272) | step 3480 | avg_nll=13.30 avg_ppl=6.31 speed=8304.61 words/sec time_elapsed=111.92 sec
# epoch 13 (225/272) | step 3490 | avg_nll=15.12 avg_ppl=8.05 speed=8418.76 words/sec time_elapsed=112.20 sec
# epoch 13 (235/272) | step 3500 | avg_nll=13.80 avg_ppl=6.76 speed=8619.56 words/sec time_elapsed=112.46 sec
# Begin validation ...
# validation: step 3500 | dev_ppl=9.813796043395996
# epoch 13 step 3500: save currently the best model to 'model.pt'
# epoch 13 (245/272) | step 3510 | avg_nll=14.71 avg_ppl=7.55 speed=5099.57 words/sec time_elapsed=112.92 sec
# epoch 13 (255/272) | step 3520 | avg_nll=13.25 avg_ppl=6.41 speed=7527.48 words/sec time_elapsed=113.22 sec
# epoch 13 (265/272) | step 3530 | avg_nll=13.86 avg_ppl=6.64 speed=8070.06 words/sec time_elapsed=113.52 sec
# epoch 14 (3/272) | step 3540 | avg_nll=14.45 avg_ppl=7.31 speed=8776.03 words/sec time_elapsed=113.78 sec
# epoch 14 (13/272) | step 3550 | avg_nll=12.19 avg_ppl=5.62 speed=8236.54 words/sec time_elapsed=114.05 sec
# epoch 14 (23/272) | step 3560 | avg_nll=13.93 avg_ppl=6.56 speed=8465.07 words/sec time_elapsed=114.33 sec
# epoch 14 (33/272) | step 3570 | avg_nll=12.93 avg_ppl=5.98 speed=8492.57 words/sec time_elapsed=114.61 sec
# epoch 14 (43/272) | step 3580 | avg_nll=13.08 avg_ppl=6.23 speed=8345.86 words/sec time_elapsed=114.88 sec
# epoch 14 (53/272) | step 3590 | avg_nll=13.13 avg_ppl=6.08 speed=8757.56 words/sec time_elapsed=115.15 sec
# epoch 14 (63/272) | step 3600 | avg_nll=14.66 avg_ppl=7.40 speed=8524.03 words/sec time_elapsed=115.42 sec
# Begin validation ...
# validation: step 3600 | dev_ppl=9.572310447692871
# epoch 14 step 3600: save currently the best model to 'model.pt'
# epoch 14 (73/272) | step 3610 | avg_nll=13.90 avg_ppl=6.76 speed=5036.12 words/sec time_elapsed=115.88 sec
# epoch 14 (83/272) | step 3620 | avg_nll=13.17 avg_ppl=6.25 speed=8474.98 words/sec time_elapsed=116.16 sec
# epoch 14 (93/272) | step 3630 | avg_nll=13.21 avg_ppl=6.19 speed=8548.76 words/sec time_elapsed=116.43 sec
# epoch 14 (103/272) | step 3640 | avg_nll=13.35 avg_ppl=6.34 speed=8599.97 words/sec time_elapsed=116.70 sec
# epoch 14 (113/272) | step 3650 | avg_nll=13.78 avg_ppl=6.69 speed=8483.05 words/sec time_elapsed=116.97 sec
# epoch 14 (123/272) | step 3660 | avg_nll=13.51 avg_ppl=6.62 speed=8534.59 words/sec time_elapsed=117.24 sec
# epoch 14 (133/272) | step 3670 | avg_nll=13.62 avg_ppl=6.33 speed=8453.59 words/sec time_elapsed=117.52 sec
# epoch 14 (143/272) | step 3680 | avg_nll=14.27 avg_ppl=7.00 speed=8704.85 words/sec time_elapsed=117.79 sec
# epoch 14 (153/272) | step 3690 | avg_nll=12.60 avg_ppl=5.91 speed=8468.79 words/sec time_elapsed=118.06 sec
# epoch 14 (163/272) | step 3700 | avg_nll=12.88 avg_ppl=6.03 speed=8335.07 words/sec time_elapsed=118.33 sec
# Begin validation ...
# validation: step 3700 | dev_ppl=9.369670867919922
# epoch 14 step 3700: save currently the best model to 'model.pt'
# epoch 14 (173/272) | step 3710 | avg_nll=13.24 avg_ppl=6.32 speed=5048.26 words/sec time_elapsed=118.79 sec
# epoch 14 (183/272) | step 3720 | avg_nll=14.09 avg_ppl=6.81 speed=8771.26 words/sec time_elapsed=119.05 sec
# epoch 14 (193/272) | step 3730 | avg_nll=14.14 avg_ppl=6.93 speed=8895.92 words/sec time_elapsed=119.32 sec
# epoch 14 (203/272) | step 3740 | avg_nll=13.09 avg_ppl=6.32 speed=8160.14 words/sec time_elapsed=119.60 sec
# epoch 14 (213/272) | step 3750 | avg_nll=14.08 avg_ppl=6.91 speed=8833.60 words/sec time_elapsed=119.86 sec
# epoch 14 (223/272) | step 3760 | avg_nll=14.16 avg_ppl=7.05 speed=8520.22 words/sec time_elapsed=120.13 sec
# epoch 14 (233/272) | step 3770 | avg_nll=13.10 avg_ppl=6.13 speed=6046.95 words/sec time_elapsed=120.51 sec
# epoch 14 (243/272) | step 3780 | avg_nll=13.41 avg_ppl=6.40 speed=6124.03 words/sec time_elapsed=120.89 sec
# epoch 14 (253/272) | step 3790 | avg_nll=14.44 avg_ppl=7.18 speed=6474.67 words/sec time_elapsed=121.25 sec
# epoch 14 (263/272) | step 3800 | avg_nll=13.35 avg_ppl=6.25 speed=5902.93 words/sec time_elapsed=121.65 sec
# Begin validation ...
# validation: step 3800 | dev_ppl=9.639144897460938
# epoch 15 (1/272) | step 3810 | avg_nll=12.70 avg_ppl=5.88 speed=3500.00 words/sec time_elapsed=122.31 sec
# epoch 15 (11/272) | step 3820 | avg_nll=13.31 avg_ppl=6.26 speed=5419.09 words/sec time_elapsed=122.73 sec
# epoch 15 (21/272) | step 3830 | avg_nll=12.61 avg_ppl=5.73 speed=5388.73 words/sec time_elapsed=123.16 sec
# epoch 15 (31/272) | step 3840 | avg_nll=12.34 avg_ppl=5.60 speed=8576.41 words/sec time_elapsed=123.43 sec
# epoch 15 (41/272) | step 3850 | avg_nll=13.05 avg_ppl=5.83 speed=7797.06 words/sec time_elapsed=123.73 sec
# epoch 15 (51/272) | step 3860 | avg_nll=12.42 avg_ppl=5.56 speed=8306.11 words/sec time_elapsed=124.01 sec
# epoch 15 (61/272) | step 3870 | avg_nll=14.00 avg_ppl=6.94 speed=8828.63 words/sec time_elapsed=124.28 sec
# epoch 15 (71/272) | step 3880 | avg_nll=12.43 avg_ppl=5.62 speed=8573.13 words/sec time_elapsed=124.55 sec
# epoch 15 (81/272) | step 3890 | avg_nll=13.08 avg_ppl=6.11 speed=8082.64 words/sec time_elapsed=124.83 sec
# epoch 15 (91/272) | step 3900 | avg_nll=12.90 avg_ppl=5.95 speed=8512.10 words/sec time_elapsed=125.10 sec
# Begin validation ...
# validation: step 3900 | dev_ppl=8.999734878540039
# epoch 15 step 3900: save currently the best model to 'model.pt'
# epoch 15 (101/272) | step 3910 | avg_nll=12.92 avg_ppl=5.98 speed=5029.47 words/sec time_elapsed=125.56 sec
# epoch 15 (111/272) | step 3920 | avg_nll=12.96 avg_ppl=6.18 speed=8021.68 words/sec time_elapsed=125.85 sec
# epoch 15 (121/272) | step 3930 | avg_nll=12.17 avg_ppl=5.42 speed=8282.11 words/sec time_elapsed=126.13 sec
# epoch 15 (131/272) | step 3940 | avg_nll=13.95 avg_ppl=6.43 speed=8946.21 words/sec time_elapsed=126.39 sec
# epoch 15 (141/272) | step 3950 | avg_nll=12.41 avg_ppl=5.49 speed=8188.00 words/sec time_elapsed=126.68 sec
# epoch 15 (151/272) | step 3960 | avg_nll=12.72 avg_ppl=5.95 speed=8494.89 words/sec time_elapsed=126.95 sec
# epoch 15 (161/272) | step 3970 | avg_nll=13.30 avg_ppl=6.36 speed=8588.92 words/sec time_elapsed=127.21 sec
# epoch 15 (171/272) | step 3980 | avg_nll=13.01 avg_ppl=6.21 speed=6522.19 words/sec time_elapsed=127.56 sec
# epoch 15 (181/272) | step 3990 | avg_nll=12.97 avg_ppl=5.96 speed=8179.88 words/sec time_elapsed=127.85 sec
# epoch 15 (191/272) | step 4000 | avg_nll=12.92 avg_ppl=6.02 speed=8413.63 words/sec time_elapsed=128.12 sec
# Begin validation ...
# validation: step 4000 | dev_ppl=9.05955696105957
# epoch 15 (201/272) | step 4010 | avg_nll=13.12 avg_ppl=6.10 speed=5436.02 words/sec time_elapsed=128.55 sec
# epoch 15 (211/272) | step 4020 | avg_nll=13.04 avg_ppl=5.92 speed=8527.23 words/sec time_elapsed=128.82 sec
# epoch 15 (221/272) | step 4030 | avg_nll=13.84 avg_ppl=6.70 speed=8262.53 words/sec time_elapsed=129.11 sec
# epoch 15 (231/272) | step 4040 | avg_nll=13.03 avg_ppl=6.06 speed=8734.41 words/sec time_elapsed=129.37 sec
# epoch 15 (241/272) | step 4050 | avg_nll=13.59 avg_ppl=6.34 speed=8865.74 words/sec time_elapsed=129.64 sec
# epoch 15 (251/272) | step 4060 | avg_nll=12.60 avg_ppl=5.80 speed=8142.30 words/sec time_elapsed=129.92 sec
# epoch 15 (261/272) | step 4070 | avg_nll=12.69 avg_ppl=5.79 speed=8360.29 words/sec time_elapsed=130.20 sec
# epoch 15 (271/272) | step 4080 | avg_nll=12.64 avg_ppl=5.70 speed=8522.15 words/sec time_elapsed=130.47 sec
# Reached maximum number of epochs

# %% [markdown]
# ## Evaluate the model
#
# We have trained a seq2seq model for the NMT task. Now let's evaluate the model on the test set by generating translations with beam search and comparing them to the gold translations using the BLEU score.

# %%
from tqdm import tqdm
from nltk.translate.bleu_score import corpus_bleu

def beam_search(model: EncoderDecoderModel,
                encoder_input_ids: torch.LongTensor,
                beam_width: int = 5,
                max_len: int = 32) -> Tuple[torch.LongTensor, float]:
    """Run beam search on the encoder-decoder model for a single source sequence.

    Args:
        model: The encoder-decoder model.
        encoder_input_ids: The input sequence. Tensor of shape [encoder_sequence_length].
        beam_width: Number of generations to expand at each time step.
        max_len: Stop generation when reaching this length for the generated sequence.

    Returns:
        A tuple (generation, score) where generation is the generated target sequence and
            a tensor of shape [target_sequence_length] and score is the corresponding
            log-probability of this generation.
    """
    model.eval()

    encoder_input_ids = encoder_input_ids.unsqueeze(0) # Add the batch dimension
    encoder_padding_mask = torch.zeros_like(encoder_input_ids, dtype=torch.bool) # No padding
    encoder_outputs = model.forward_encoder(encoder_input_ids, encoder_padding_mask)

    generations = [torch.tensor([target_tokenizer.bos_token_id], device=encoder_input_ids.device)]
    scores = [0.0]

    best_generation = None
    best_score = float('-inf')

    for _ in range(max_len):
        new_generations = []
        new_scores = []
        for score, generation in zip(scores, generations):
            generation = generation.unsqueeze(0) # Add the batch dimension
            padding_mask = torch.zeros_like(generation, dtype=torch.bool) # No padding
            decoder_output = model.forward_decoder(generation, padding_mask, encoder_outputs, encoder_padding_mask)
            last_log_probs = decoder_output[0, -1, :].log_softmax(dim=-1)
            top_log_probs, top_indices = last_log_probs.topk(beam_width, dim=-1)

            new_generations.append(torch.cat([generation.expand(beam_width, -1), top_indices[:,None]], dim=1))
            new_scores.append(score + top_log_probs)

        new_generations = torch.cat(new_generations, dim=0)
        new_scores = torch.cat(new_scores, dim=0)

        ends_with_eos = target_tokenizer.eos_token_id == new_generations[:,-1]

        if ends_with_eos.any():
            new_completed_generations = new_generations[ends_with_eos]
            new_completed_scores = new_scores[ends_with_eos]

            if new_completed_scores.max() > best_score:
                best_score = new_completed_scores.max()
                best_generation = new_completed_generations[new_completed_scores.argmax()]

        if best_score >= new_scores.max():
            break

        scores, indices = torch.topk(new_scores, beam_width, dim=-1)
        generations = new_generations[indices]

    if best_generation is None:
        best_generation = generations[0]
        best_score = scores[0]

    return best_generation, best_score.cpu().item()


def run_generation(model, test_dataset, beam_size=5, max_decoding_time_step=32):
    """Run beam search decoding on the test set, compute BLEU and return reference and candidate target sentences.
    """

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print('Use device: %s' % device)

    input_sentences = []
    reference_sentences = []
    candidate_sentences = []

    with torch.no_grad():
        for example in tqdm(test_dataset):
            encoder_input_ids = torch.tensor(example["encoder_input_ids"], device=device)

            generation, _ = beam_search(model, encoder_input_ids, beam_size, max_decoding_time_step)

            # Decode given source sequence and generated target sequence and avoid special tokens

            input_text = "".join(source_tokenizer.decode(token).replace("▁", " ") for token in example["encoder_input_ids"][1:-1])
            reference_text = "".join(target_tokenizer.decode(token).replace("▁", " ") for token in example["decoder_input_ids"][1:-1])
            candidate_text = "".join(target_tokenizer.decode(token).replace("▁", " ") for token in generation[1:-1].cpu())

            reference_sentences.append(reference_text)
            candidate_sentences.append(candidate_text)
            input_sentences.append(input_text)


    bleu_score = corpus_bleu([[ref] for ref in reference_sentences],
                             [candidate for candidate in candidate_sentences])

    return bleu_score, input_sentences, reference_sentences, candidate_sentences

# %%
# Restore the best validation checkpoint
model.load_state_dict(torch.load("model.pt"))

bleu_score, inputs, references, candidates = run_generation(model, tokenized_datasets["test"])
print('\n\nCorpus BLEU: {}'.format(bleu_score * 100))
# Out:
# <ipython-input-24-85e6e566cf06>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("model.pt"))
# Use device: cuda:0
# 100%|██████████| 486/486 [01:05<00:00,  7.45it/s]
# Corpus BLEU: 46.31596322557168

# %% [markdown]
# Let's look at some examples. What do you think of the quality of the translations?

# %%
# Feel free to change the range to look at more samples!
for k in range(10, 20):
  print(f"===== Sample {k} =====")
  print(f"Input: {inputs[k]}")
  print(f"Gold: {references[k]}")
  print(f"Pred: {candidates[k]}")
# Out:
# ===== Sample 10 =====
# Input:  vous me mettez mal a l aise .
# Gold:  you re embarrassing me .
# Pred:  you re fussy .
# ===== Sample 11 =====
# Input:  c est toi le professeur .
# Gold:  you re the teacher .
# Pred:  you re the teacher .
# ===== Sample 12 =====
# Input:  elle sourit avec bonheur .
# Gold:  she smiled happily .
# Pred:  she is good the
# ===== Sample 13 =====
# Input:  je ne suis pas devin .
# Gold:  i m not a psychic .
# Pred:  i m not all .
# ===== Sample 14 =====
# Input:  vous allez perdre .
# Gold:  you re going to lose .
# Pred:  i m going to with you .
# ===== Sample 15 =====
# Input:  vous me touchez .
# Gold:  you re touching me .
# Pred:  you re big alike .
# ===== Sample 16 =====
# Input:  je pars aujourd hui .
# Gold:  i m leaving today .
# Pred:  i m happy .
# ===== Sample 17 =====
# Input:  je ne suis pas une sainte .
# Gold:  i m no saint .
# Pred:  i m not a us .
# ===== Sample 18 =====
# Input:  je suis puissant .
# Gold:  i m powerful .
# Pred:  i m anything .
# ===== Sample 19 =====
# Input:  vous n etes qu un lache .
# Gold:  you re nothing but a coward .
# Pred:  you re not dead .

# %% [markdown]
# # Questions
#
# Please answer written questions from the assignment in this section. You can alter the provided code to obtain the answers, but be careful not to break anything!
#
# **(b) (4 points)**
#
# - (i)
#     What vocabulary size are we using for the source and target language?
#
# - (ii)
#     Approximately how many source and target tokens are on average contained in a training batch? What proportion of these tokens are `<pad>` tokens on average?
#
# - (iii)
# What is the specific purpose of saving the model parameters in a file `model.pt` throughout training in the code we provide?
#
# **(c) (2 points)**
# Manually look at some results and compare them with the gold answers. What do you think of the quality of the translations? Are these grammatical English sentences? Can you identify any common mistakes?
#
# **(d) (4 points)**
# Consider the provided beam search method. This implementation is not efficient and performs a lot of repeated computation. Identify the issue and propose how you can fix it.
# In particular, describe how would you have to change the arguments and return values of your EncoderDecoderModel and its sub-modules?
